# %% [markdown]
# # TELECOM CHURN CASE STUDY

# %% [markdown]
# ![](https://krishastudio.com/wp-content/uploads/2021/06/Main-1.gif)

# %% [markdown]
# ###  *Business Objective*
# To predict churn for the high value customers churn(Usage- Based Churn) in the last (i.e the ninth /September) month using the data from the first three months(June, July, and August).
#
# ### *Goals*
# - Perform EDA
# - Filter High value customers.
# - Build Models : To predict whether a high value customer will churn or not, in near future(i.e churn phase- 9th month)
# - Build Model  : To identify important variables that are strong predictors of churn.
# - Strategies to manage customer churn.

# %%
#Importing required libraries

import numpy as np
import pandas as pd
import time
from numpy.random import randn
from itertools    import combinations

import matplotlib.pyplot as plt
import seaborn as sns

from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler
from sklearn.decomposition import PCA
from sklearn.decomposition import IncrementalPCA
from sklearn.feature_selection import RFE
from statsmodels.stats.outliers_influence import variance_inflation_factor
from sklearn.model_selection import GridSearchCV,RandomizedSearchCV

from sklearn.linear_model import LogisticRegression
from sklearn.tree import DecisionTreeClassifier
from sklearn.ensemble import RandomForestClassifier
from sklearn.neighbors import KNeighborsClassifier 

from sklearn import metrics

#Supress warnings
import warnings
warnings.filterwarnings('ignore')

# %%
#Read the Dataset.
telecom = pd.read_csv("telecom_churn_data.csv")
telecom.head()
# Out:
#    mobile_number  circle_id  loc_og_t2o_mou  std_og_t2o_mou  loc_ic_t2o_mou  \
# 0     7000842753        109             0.0             0.0             0.0
# 1     7001865778        109             0.0             0.0             0.0
# 2     7001625959        109             0.0             0.0             0.0
# 3     7001204172        109             0.0             0.0             0.0
# 4     7000142493        109             0.0             0.0             0.0
#
#   last_date_of_month_6 last_date_of_month_7 last_date_of_month_8  \
# 0            6/30/2014            7/31/2014            8/31/2014
# 1            6/30/2014            7/31/2014            8/31/2014
# 2            6/30/2014            7/31/2014            8/31/2014
# 3            6/30/2014            7/31/2014            8/31/2014
# 4            6/30/2014            7/31/2014            8/31/2014
#
#   last_date_of_month_9   arpu_6  ...  sachet_3g_9  fb_user_6  fb_user_7  \
# 0            9/30/2014  197.385  ...            0        1.0        1.0
# 1            9/30/2014   34.047  ...            0        NaN        1.0
# 2            9/30/2014  167.690  ...            0        NaN        NaN
# 3            9/30/2014  221.338  ...            0        NaN        NaN
# 4            9/30/2014  261.636  ...            0        0.0        NaN
#
#    fb_user_8  fb_user_9   aon  aug_vbc_3g  jul_vbc_3g  jun_vbc_3g  sep_vbc_3g
# 0        1.0        NaN   968        30.4         0.0      101.20        3.58
# 1        1.0        NaN  1006         0.0         0.0        0.00        0.00
# 2        NaN        1.0  1103         0.0         0.0        4.17        0.00
# 3        NaN        NaN  2491         0.0         0.0        0.00        0.00
# 4        NaN        NaN  1526         0.0         0.0        0.00        0.00
#
# [5 rows x 226 columns]

# %% [markdown]
# # EDA

# %%
#Data type and Non-Null count of varaibles present in the data set.
telecom.info(verbose=True,null_counts=True)
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 99999 entries, 0 to 99998
# Data columns (total 226 columns):
#  #    Column                    Non-Null Count  Dtype
# ---   ------                    --------------  -----
#  0    mobile_number             99999 non-null  int64
#  1    circle_id                 99999 non-null  int64
#  2    loc_og_t2o_mou            98981 non-null  float64
#  3    std_og_t2o_mou            98981 non-null  float64
#  4    loc_ic_t2o_mou            98981 non-null  float64
#  5    last_date_of_month_6      99999 non-null  object
#  6    last_date_of_month_7      99398 non-null  object
#  7    last_date_of_month_8      98899 non-null  object
#  8    last_date_of_month_9      98340 non-null  object
#  9    arpu_6                    99999 non-null  float64
#  10   arpu_7                    99999 non-null  float64
#  11   arpu_8                    99999 non-null  float64
#  12   arpu_9                    99999 non-null  float64
#  13   onnet_mou_6               96062 non-null  float64
#  14   onnet_mou_7               96140 non-null  float64
#  15   onnet_mou_8               94621 non-null  float64
#  16   onnet_mou_9               92254 non-null  float64
#  17   offnet_mou_6              96062 non-null  float64
#  18   offnet_mou_7              96140 non-null  float64
#  19   offnet_mou_8              94621 non-null  float64
#  20   offnet_mou_9              92254 non-null  float64
#  21   roam_ic_mou_6             96062 non-null  float64
#  22   roam_ic_mou_7             96140 non-null  float64
#  23   roam_ic_mou_8             94621 non-null  float64
#  24   roam_ic_mou_9             92254 non-null  float64
#  25   roam_og_mou_6             96062 non-null  float64
#  26   roam_og_mou_7             96140 non-null  float64
#  27   roam_og_mou_8             94621 non-null  float64
#  28   roam_og_mou_9             92254 non-null  float64
#  29   loc_og_t2t_mou_6          96062 non-null  float64
#  30   loc_og_t2t_mou_7          96140 non-null  float64
#  31   loc_og_t2t_mou_8          94621 non-null  float64
#  32   loc_og_t2t_mou_9          92254 non-null  float64
#  33   loc_og_t2m_mou_6          96062 non-null  float64
#  34   loc_og_t2m_mou_7          96140 non-null  float64
#  35   loc_og_t2m_mou_8          94621 non-null  float64
#  36   loc_og_t2m_mou_9          92254 non-null  float64
#  37   loc_og_t2f_mou_6          96062 non-null  float64
#  38   loc_og_t2f_mou_7          96140 non-null  float64
#  39   loc_og_t2f_mou_8          94621 non-null  float64
#  40   loc_og_t2f_mou_9          92254 non-null  float64
#  41   loc_og_t2c_mou_6          96062 non-null  float64
#  42   loc_og_t2c_mou_7          96140 non-null  float64
#  43   loc_og_t2c_mou_8          94621 non-null  float64
#  44   loc_og_t2c_mou_9          92254 non-null  float64
#  45   loc_og_mou_6              96062 non-null  float64
#  46   loc_og_mou_7              96140 non-null  float64
#  47   loc_og_mou_8              94621 non-null  float64
#  48   loc_og_mou_9              92254 non-null  float64
#  49   std_og_t2t_mou_6          96062 non-null  float64
#  50   std_og_t2t_mou_7          96140 non-null  float64
#  51   std_og_t2t_mou_8          94621 non-null  float64
#  52   std_og_t2t_mou_9          92254 non-null  float64
#  53   std_og_t2m_mou_6          96062 non-null  float64
#  54   std_og_t2m_mou_7          96140 non-null  float64
#  55   std_og_t2m_mou_8          94621 non-null  float64
#  56   std_og_t2m_mou_9          92254 non-null  float64
#  57   std_og_t2f_mou_6          96062 non-null  float64
#  58   std_og_t2f_mou_7          96140 non-null  float64
#  59   std_og_t2f_mou_8          94621 non-null  float64
#  60   std_og_t2f_mou_9          92254 non-null  float64
#  61   std_og_t2c_mou_6          96062 non-null  float64
#  62   std_og_t2c_mou_7          96140 non-null  float64
#  63   std_og_t2c_mou_8          94621 non-null  float64
#  64   std_og_t2c_mou_9          92254 non-null  float64
#  65   std_og_mou_6              96062 non-null  float64
#  66   std_og_mou_7              96140 non-null  float64
#  67   std_og_mou_8              94621 non-null  float64
#  68   std_og_mou_9              92254 non-null  float64
#  69   isd_og_mou_6              96062 non-null  float64
#  70   isd_og_mou_7              96140 non-null  float64
#  71   isd_og_mou_8              94621 non-null  float64
#  72   isd_og_mou_9              92254 non-null  float64
#  73   spl_og_mou_6              96062 non-null  float64
#  74   spl_og_mou_7              96140 non-null  float64
#  75   spl_og_mou_8              94621 non-null  float64
#  76   spl_og_mou_9              92254 non-null  float64
#  77   og_others_6               96062 non-null  float64
#  78   og_others_7               96140 non-null  float64
#  79   og_others_8               94621 non-null  float64
#  80   og_others_9               92254 non-null  float64
#  81   total_og_mou_6            99999 non-null  float64
#  82   total_og_mou_7            99999 non-null  float64
#  83   total_og_mou_8            99999 non-null  float64
#  84   total_og_mou_9            99999 non-null  float64
#  85   loc_ic_t2t_mou_6          96062 non-null  float64
#  86   loc_ic_t2t_mou_7          96140 non-null  float64
#  87   loc_ic_t2t_mou_8          94621 non-null  float64
#  88   loc_ic_t2t_mou_9          92254 non-null  float64
#  89   loc_ic_t2m_mou_6          96062 non-null  float64
#  90   loc_ic_t2m_mou_7          96140 non-null  float64
#  91   loc_ic_t2m_mou_8          94621 non-null  float64
#  92   loc_ic_t2m_mou_9          92254 non-null  float64
#  93   loc_ic_t2f_mou_6          96062 non-null  float64
#  94   loc_ic_t2f_mou_7          96140 non-null  float64
#  95   loc_ic_t2f_mou_8          94621 non-null  float64
#  96   loc_ic_t2f_mou_9          92254 non-null  float64
#  97   loc_ic_mou_6              96062 non-null  float64
#  98   loc_ic_mou_7              96140 non-null  float64
#  99   loc_ic_mou_8              94621 non-null  float64
#  100  loc_ic_mou_9              92254 non-null  float64
#  101  std_ic_t2t_mou_6          96062 non-null  float64
#  102  std_ic_t2t_mou_7          96140 non-null  float64
#  103  std_ic_t2t_mou_8          94621 non-null  float64
#  104  std_ic_t2t_mou_9          92254 non-null  float64
#  105  std_ic_t2m_mou_6          96062 non-null  float64
#  106  std_ic_t2m_mou_7          96140 non-null  float64
#  107  std_ic_t2m_mou_8          94621 non-null  float64
#  108  std_ic_t2m_mou_9          92254 non-null  float64
#  109  std_ic_t2f_mou_6          96062 non-null  float64
#  110  std_ic_t2f_mou_7          96140 non-null  float64
#  111  std_ic_t2f_mou_8          94621 non-null  float64
#  112  std_ic_t2f_mou_9          92254 non-null  float64
#  113  std_ic_t2o_mou_6          96062 non-null  float64
#  114  std_ic_t2o_mou_7          96140 non-null  float64
#  115  std_ic_t2o_mou_8          94621 non-null  float64
#  116  std_ic_t2o_mou_9          92254 non-null  float64
#  117  std_ic_mou_6              96062 non-null  float64
#  118  std_ic_mou_7              96140 non-null  float64
#  119  std_ic_mou_8              94621 non-null  float64
#  120  std_ic_mou_9              92254 non-null  float64
#  121  total_ic_mou_6            99999 non-null  float64
#  122  total_ic_mou_7            99999 non-null  float64
#  123  total_ic_mou_8            99999 non-null  float64
#  124  total_ic_mou_9            99999 non-null  float64
#  125  spl_ic_mou_6              96062 non-null  float64
#  126  spl_ic_mou_7              96140 non-null  float64
#  127  spl_ic_mou_8              94621 non-null  float64
#  128  spl_ic_mou_9              92254 non-null  float64
#  129  isd_ic_mou_6              96062 non-null  float64
#  130  isd_ic_mou_7              96140 non-null  float64
#  131  isd_ic_mou_8              94621 non-null  float64
#  132  isd_ic_mou_9              92254 non-null  float64
#  133  ic_others_6               96062 non-null  float64
#  134  ic_others_7               96140 non-null  float64
#  135  ic_others_8               94621 non-null  float64
#  136  ic_others_9               92254 non-null  float64
#  137  total_rech_num_6          99999 non-null  int64
#  138  total_rech_num_7          99999 non-null  int64
#  139  total_rech_num_8          99999 non-null  int64
#  140  total_rech_num_9          99999 non-null  int64
#  141  total_rech_amt_6          99999 non-null  int64
#  142  total_rech_amt_7          99999 non-null  int64
#  143  total_rech_amt_8          99999 non-null  int64
#  144  total_rech_amt_9          99999 non-null  int64
#  145  max_rech_amt_6            99999 non-null  int64
#  146  max_rech_amt_7            99999 non-null  int64
#  147  max_rech_amt_8            99999 non-null  int64
#  148  max_rech_amt_9            99999 non-null  int64
#  149  date_of_last_rech_6       98392 non-null  object
#  150  date_of_last_rech_7       98232 non-null  object
#  151  date_of_last_rech_8       96377 non-null  object
#  152  date_of_last_rech_9       95239 non-null  object
#  153  last_day_rch_amt_6        99999 non-null  int64
#  154  last_day_rch_amt_7        99999 non-null  int64
#  155  last_day_rch_amt_8        99999 non-null  int64
#  156  last_day_rch_amt_9        99999 non-null  int64
#  157  date_of_last_rech_data_6  25153 non-null  object
#  158  date_of_last_rech_data_7  25571 non-null  object
#  159  date_of_last_rech_data_8  26339 non-null  object
#  160  date_of_last_rech_data_9  25922 non-null  object
#  161  total_rech_data_6         25153 non-null  float64
#  162  total_rech_data_7         25571 non-null  float64
#  163  total_rech_data_8         26339 non-null  float64
#  164  total_rech_data_9         25922 non-null  float64
#  165  max_rech_data_6           25153 non-null  float64
#  166  max_rech_data_7           25571 non-null  float64
#  167  max_rech_data_8           26339 non-null  float64
#  168  max_rech_data_9           25922 non-null  float64
#  169  count_rech_2g_6           25153 non-null  float64
#  170  count_rech_2g_7           25571 non-null  float64
#  171  count_rech_2g_8           26339 non-null  float64
#  172  count_rech_2g_9           25922 non-null  float64
#  173  count_rech_3g_6           25153 non-null  float64
#  174  count_rech_3g_7           25571 non-null  float64
#  175  count_rech_3g_8           26339 non-null  float64
#  176  count_rech_3g_9           25922 non-null  float64
#  177  av_rech_amt_data_6        25153 non-null  float64
#  178  av_rech_amt_data_7        25571 non-null  float64
#  179  av_rech_amt_data_8        26339 non-null  float64
#  180  av_rech_amt_data_9        25922 non-null  float64
#  181  vol_2g_mb_6               99999 non-null  float64
#  182  vol_2g_mb_7               99999 non-null  float64
#  183  vol_2g_mb_8               99999 non-null  float64
#  184  vol_2g_mb_9               99999 non-null  float64
#  185  vol_3g_mb_6               99999 non-null  float64
#  186  vol_3g_mb_7               99999 non-null  float64
#  187  vol_3g_mb_8               99999 non-null  float64
#  188  vol_3g_mb_9               99999 non-null  float64
#  189  arpu_3g_6                 25153 non-null  float64
#  190  arpu_3g_7                 25571 non-null  float64
#  191  arpu_3g_8                 26339 non-null  float64
#  192  arpu_3g_9                 25922 non-null  float64
#  193  arpu_2g_6                 25153 non-null  float64
#  194  arpu_2g_7                 25571 non-null  float64
#  195  arpu_2g_8                 26339 non-null  float64
#  196  arpu_2g_9                 25922 non-null  float64
#  197  night_pck_user_6          25153 non-null  float64
#  198  night_pck_user_7          25571 non-null  float64
#  199  night_pck_user_8          26339 non-null  float64
#  200  night_pck_user_9          25922 non-null  float64
#  201  monthly_2g_6              99999 non-null  int64
#  202  monthly_2g_7              99999 non-null  int64
#  203  monthly_2g_8              99999 non-null  int64
#  204  monthly_2g_9              99999 non-null  int64
#  205  sachet_2g_6               99999 non-null  int64
#  206  sachet_2g_7               99999 non-null  int64
#  207  sachet_2g_8               99999 non-null  int64
#  208  sachet_2g_9               99999 non-null  int64
#  209  monthly_3g_6              99999 non-null  int64
#  210  monthly_3g_7              99999 non-null  int64
#  211  monthly_3g_8              99999 non-null  int64
#  212  monthly_3g_9              99999 non-null  int64
#  213  sachet_3g_6               99999 non-null  int64
#  214  sachet_3g_7               99999 non-null  int64
#  215  sachet_3g_8               99999 non-null  int64
#  216  sachet_3g_9               99999 non-null  int64
#  217  fb_user_6                 25153 non-null  float64
#  218  fb_user_7                 25571 non-null  float64
#  219  fb_user_8                 26339 non-null  float64
#  220  fb_user_9                 25922 non-null  float64
#  221  aon                       99999 non-null  int64
#  222  aug_vbc_3g                99999 non-null  float64
#  223  jul_vbc_3g                99999 non-null  float64
#  224  jun_vbc_3g                99999 non-null  float64
#  225  sep_vbc_3g                99999 non-null  float64
# dtypes: float64(179), int64(35), object(12)
# memory usage: 172.4+ MB

# %%
#Observation : All the date columns in the dataset have a datatype of an object.
#Convert date columns in the dataset from Object to Date
for i in telecom.select_dtypes('object'):
    telecom[i] = pd.to_datetime(telecom[i])

#Print all the columns that contains datetime values
telecom.select_dtypes('datetime64[ns]').info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 99999 entries, 0 to 99998
# Data columns (total 12 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   last_date_of_month_6      99999 non-null  datetime64[ns]
#  1   last_date_of_month_7      99398 non-null  datetime64[ns]
#  2   last_date_of_month_8      98899 non-null  datetime64[ns]
#  3   last_date_of_month_9      98340 non-null  datetime64[ns]
#  4   date_of_last_rech_6       98392 non-null  datetime64[ns]
#  5   date_of_last_rech_7       98232 non-null  datetime64[ns]
#  6   date_of_last_rech_8       96377 non-null  datetime64[ns]
#  7   date_of_last_rech_9       95239 non-null  datetime64[ns]
#  8   date_of_last_rech_data_6  25153 non-null  datetime64[ns]
#  9   date_of_last_rech_data_7  25571 non-null  datetime64[ns]
#  10  date_of_last_rech_data_8  26339 non-null  datetime64[ns]
#  11  date_of_last_rech_data_9  25922 non-null  datetime64[ns]
# dtypes: datetime64[ns](12)
# memory usage: 9.2 MB

# %%
#Null values percentage count
#pd.set_option('display.max_rows', None)
nullCount = pd.DataFrame(round(telecom.isnull().sum()[telecom.isnull().sum()>1]/telecom.shape[0] * 100,2),columns=['NullPercentage'])
nullCount.sort_values(by="NullPercentage",ascending=False)
# Out:
#                       NullPercentage
# count_rech_2g_6                74.85
# max_rech_data_6                74.85
# arpu_3g_6                      74.85
# av_rech_amt_data_6             74.85
# count_rech_3g_6                74.85
# ...                              ...
# last_date_of_month_8            1.10
# std_og_t2o_mou                  1.02
# loc_ic_t2o_mou                  1.02
# loc_og_t2o_mou                  1.02
# last_date_of_month_7            0.60
#
# [166 rows x 1 columns]

# %%
#Drop columns which have more than 70% Null values
telecom = telecom.dropna(thresh=telecom.shape[0]*0.7,how='all',axis=1)
telecom.shape
# Out:
# (99999, 186)

# %%
#Null values percentage after droping the variables
nullCount = pd.DataFrame(round(telecom.isnull().sum()[telecom.isnull().sum()>1]/telecom.shape[0] * 100,2),columns=['NullPercentage'])
nullCount.sort_values(by="NullPercentage",ascending=False)
# Out:
#                       NullPercentage
# loc_og_t2f_mou_9                7.75
# loc_og_t2t_mou_9                7.75
# std_ic_t2o_mou_9                7.75
# loc_og_mou_9                    7.75
# roam_og_mou_9                   7.75
# ...                              ...
# last_date_of_month_8            1.10
# std_og_t2o_mou                  1.02
# loc_ic_t2o_mou                  1.02
# loc_og_t2o_mou                  1.02
# last_date_of_month_7            0.60
#
# [126 rows x 1 columns]

# %%
#Fill all the Null values with 0
telecom = telecom.fillna(0)

# %% [markdown]
# # Derived Metrics

# %%
#Create a new metric arpu_diff - Average revenue per user difference between action phase(8) and mean of good phase(6,7)
telecom['arpu_diff'] = telecom['arpu_8'] - (telecom['arpu_6']+telecom['arpu_7'])/2

# %%
#Create a new metric AON_Y  - Approx number of years the customer is using the operator T network
bins = [0, 1, 2, 4, 6, 8, 12]
labels = ["<1 Year","1-2 Year","2-4 Year","4-6 Year","6-8 Year",">8 Year"]
telecom['AON_Y'] = pd.cut((telecom['aon']/365),bins=bins, labels=labels).astype('object')

# %%
#Create a new metric TotalRech-2G - Total number of recharge for 2G Data
telecom['TotalRech-2G'] = 0
for i in range(6,9):
    telecom['TotalRech-2G'] += telecom['monthly_2g_'+str(i)]+telecom['sachet_2g_'+str(i)]

# %%
#Create a new metric TotalRech-3G - Total number of recharge for 3G Data
telecom['TotalRech-3G'] = 0
for i in range(6,9):
    telecom['TotalRech-3G'] += telecom['monthly_3g_'+str(i)]+telecom['sachet_3g_'+str(i)]

# %%
#Create a new metric TotalRech_2G-3G - Total number of recharge for Internet(2G+3G)
telecom['TotalRech_2G-3G'] = telecom['TotalRech-2G'] + telecom['TotalRech-3G']

# %%
#Create a new metric to identify which whether user using Internet or not.
telecom['InternetUser'] = np.where(telecom['TotalRech-2G'] + telecom['TotalRech-3G'] > 0 , 1 , 0)

# %%
#Create a new metric TotalRech-Call - Total number of recharge.
telecom['TotalRech-Call'] = 0
for i in range(6,9):
    telecom['TotalRech-Call'] += telecom['total_rech_num_'+str(i)]

# %%
#Create a new metric TotalRech-Call - Total recharge amount for call.
telecom['TotalRech-Call_Amnt'] = 0
for i in range(6,9):
    telecom['TotalRech-Call_Amnt'] += telecom['total_rech_amt_'+str(i)]

# %%
#Create a new metric that tells the type of customer e.g only used for calling, Using only Internet,
#using both Calling and Internet, and None (Uses neither calling nor Internet)

#uType function that categorise the User based on services used
def uType(row):
    if (row['TotalRech_2G-3G'] ==0 and row['TotalRech-Call'] > 0):
        userType= "Calling Service Only"
    elif (row['TotalRech_2G-3G'] >0 and row['TotalRech-Call'] == 0):
         userType= "Internet Service Only"
    elif (row['TotalRech_2G-3G'] >0 and row['TotalRech-Call']> 0):
        userType = "Both Call & Internet"
    else:
        userType = "None"
    return userType

telecom['UserType']= telecom.apply(uType,axis=1)

# %%
#Create a new metric that tells total internet used by the user in three month
telecom['TotalDataUsed'] = 0
for i in range(6,9):
    telecom['TotalDataUsed'] += telecom['vol_2g_mb_'+str(i)] + telecom['vol_3g_mb_'+str(i)]

telecom['TotalDataUsed'] = round((telecom['TotalDataUsed']),2)

# %%
#Create a new metric that tells total call time of a user in three month
telecom['TotalCallTime'] = 0
for i in range(6,9):
    telecom['TotalCallTime'] += telecom['total_ic_mou_'+str(i)] + telecom['total_og_mou_'+str(i)]

telecom['TotalCallTime'] = round(telecom['TotalCallTime']/60,2)  #Convert to Hour

# %% [markdown]
# ## Filter High Value Customers

# %%
#Filter High value customers.
#threshold : Customer who have recharged more than and equal to 7oth percentile of the average recharge amount in the first two months(Good Phase)
threshold = ((telecom['total_rech_amt_6']+telecom['total_rech_amt_7'])/2)

# %%
telecomfilter = telecom[(telecom['total_rech_amt_6']+telecom['total_rech_amt_7'])/2 >=threshold.quantile(q=0.7)]

#Shape of data frame after customer filter
telecomfilter.shape
# Out:
# (30011, 197)

# %% [markdown]
# ## Tag Churners

# %%
#Tag the churned customer (Churn=1, else=0) using total_ic_mou_9,total_og_mou_9,vol_2g_mb_9,and vol_3g_mb_9
telecomfilter['Churn'] = np.where(telecomfilter['total_ic_mou_9']+telecomfilter['total_og_mou_9']+telecomfilter['vol_2g_mb_9']
                                 + telecomfilter['vol_3g_mb_9'] == 0, 1 , 0)

# %%
#Count number of churn customers.
telecomfilter['Churn'].value_counts()
# Out:
# 0    27418
# 1     2593
# Name: Churn, dtype: int64

# %%
#Remove all the attributes corresponding to the Churn Phase(all the attributes having "_9" in their names).
telecomfilter = telecomfilter[telecomfilter.columns.drop(list(telecomfilter.filter(regex='_9')))]
telecomfilter = telecomfilter.drop(columns='sep_vbc_3g',axis=1)

#Shape of dataframe after dropping the column.
telecomfilter.shape
# Out:
# (30011, 153)

# %%
telecomfilter.head()
# Out:
#     mobile_number  circle_id  loc_og_t2o_mou  std_og_t2o_mou  loc_ic_t2o_mou  \
# 7      7000701601        109             0.0             0.0             0.0
# 8      7001524846        109             0.0             0.0             0.0
# 13     7002191713        109             0.0             0.0             0.0
# 16     7000875565        109             0.0             0.0             0.0
# 17     7000187447        109             0.0             0.0             0.0
#
#    last_date_of_month_6 last_date_of_month_7 last_date_of_month_8    arpu_6  \
# 7            2014-06-30  2014-07-31 00:00:00  2014-08-31 00:00:00  1069.180
# 8            2014-06-30  2014-07-31 00:00:00  2014-08-31 00:00:00   378.721
# 13           2014-06-30  2014-07-31 00:00:00  2014-08-31 00:00:00   492.846
# 16           2014-06-30  2014-07-31 00:00:00  2014-08-31 00:00:00   430.975
# 17           2014-06-30  2014-07-31 00:00:00  2014-08-31 00:00:00   690.008
#
#       arpu_7  ...  TotalRech-2G  TotalRech-3G  TotalRech_2G-3G  InternetUser  \
# 7   1349.850  ...             0             0                0             0
# 8    492.223  ...             5             0                5             1
# 13   205.671  ...             3             0                3             1
# 16   299.869  ...             0             0                0             0
# 17    18.980  ...             0             0                0             0
#
#     TotalRech-Call  TotalRech-Call_Amnt              UserType  TotalDataUsed  \
# 7               17                 6008  Calling Service Only           0.00
# 8               54                 1158  Both Call & Internet        1118.92
# 13              21                 1477  Both Call & Internet           0.02
# 16              18                 1078  Calling Service Only           0.00
# 17              25                  846  Calling Service Only           0.00
#
#     TotalCallTime  Churn
# 7           51.00      1
# 8           21.01      0
# 13          73.34      0
# 16          31.78      0
# 17          22.41      0
#
# [5 rows x 153 columns]

# %% [markdown]
# # Outlier Treatment

# %%
#Outlier detection
(telecomfilter.describe(percentiles=[0.01,0.05,0.9,0.98,0.99]).T).style.format("{:.1f}")
# Out:
# <style type="text/css">
# </style>
# <table id="T_6b631_">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th class="col_heading level0 col0" >count</th>
#       <th class="col_heading level0 col1" >mean</th>
#       <th class="col_heading level0 col2" >std</th>
#       <th class="col_heading level0 col3" >min</th>
#       <th class="col_heading level0 col4" >1%</th>
#       <th class="col_heading level0 col5" >5%</th>
#       <th class="col_heading level0 col6" >50%</th>
#       <th class="col_heading level0 col7" >90%</th>
#       <th class="col_heading level0 col8" >98%</th>
#       <th class="col_heading level0 col9" >99%</th>
#       <th class="col_heading level0 col10" >max</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_6b631_level0_row0" class="row_heading level0 row0" >mobile_number</th>
#       <td id="T_6b631_row0_col0" class="data row0 col0" >30011.0</td>
#       <td id="T_6b631_row0_col1" class="data row0 col1" >7001222923.6</td>
#       <td id="T_6b631_row0_col2" class="data row0 col2" >684640.5</td>
#       <td id="T_6b631_row0_col3" class="data row0 col3" >7000000074.0</td>
#       <td id="T_6b631_row0_col4" class="data row0 col4" >7000027770.4</td>
#       <td id="T_6b631_row0_col5" class="data row0 col5" >7000137611.0</td>
#       <td id="T_6b631_row0_col6" class="data row0 col6" >7001231966.0</td>
#       <td id="T_6b631_row0_col7" class="data row0 col7" >7002167078.0</td>
#       <td id="T_6b631_row0_col8" class="data row0 col8" >7002363027.4</td>
#       <td id="T_6b631_row0_col9" class="data row0 col9" >7002386671.9</td>
#       <td id="T_6b631_row0_col10" class="data row0 col10" >7002410905.0</td>
#     </tr>
#     <tr>
#       <th id="T_6b631_level0_row1" class="row_heading level0 row1" >circle_id</th>
#       <td id="T_6b631_row1_col0" class="data row1 col0" >30011.0</td>
#       <td id="T_6b631_row1_col1" class="data row1 col1" >109.0</td>
#       <td id="T_6b631_row1_col2" class="data row1 col2" >0.0</td>
#       <td id="T_6b631_row1_col3" class="data row1 col3" >109.0</td>
#       <td id="T_6b631_row1_col4" class="data row1 col4" >109.0</td>
#       <td id="T_6b631_row1_col5" class="data row1 col5" >109.0</td>
#       <td id="T_6b631_row1_col6" class="data row1 col6" >109.0</td>
#       <td id="T_6b631_row1_col7" class="data row1 col7" >109.0</td>
#       <td id="T_6b631_row1_col8" class="data row1 col8" >109.0</td>
#       <td id="T_6b631_row1_col9" class="data row1 col9" >109.0</td>
#       <td id="T_6b631_row1_col10" class="data row1 col10" >109.0</td>
#     </tr>
#     <tr>
#       <th id="T_6b631_level0_row2" class="row_heading level0 row2" >loc_og_t2o_mou</th>
#       <td id="T_6b631_row2_col0" class="data row2 col0" >30011.0</td>
#       <td id="T_6b631_row2_col1" class="data row2 col1" >0.0</td>
#       <td id="T_6b631_row2_col2" class="data row2 col2" >0.0</td>
#       <td id="T_6b631_row2_col3" class="data row2 col3" >0.0</td>
#       <td id="T_6b631_row2_col4" class="data row2 col4" >0.0</td>
#       <td id="T_6b631_row2_col5" class="data row2 col5" >0.0</td>
#       <td id="T_6b631_row2_col6" class="data row2 col6" >0.0</td>
#       <td id="T_6b631_row2_col7" class="data row2 col7" >0.0</td>
#       <td id="T_6b631_row2_col8" class="data row2 col8" >0.0</td>
#       <td id="T_6b631_row2_col9" class="data row2 col9" >0.0</td>
#       <td id="T_6b631_row2_col10" class="data row2 col10" >0.0</td>
#     </tr>
#     <tr>
#       <th id="T_6b631_level0_row3" class="row_heading level0 row3" >std_og_t2o_mou</th>
#       <td id="T_6b631_row3_col0" class="data row3 col0" >30011.0</td>
#       <td id="T_6b631_row3_col1" class="data row3 col1" >0.0</td>
#       <td id="T_6b631_row3_col2" class="data row3 col2" >0.0</td>
#       <td id="T_6b631_row3_col3" class="data row3 col3" >0.0</td>
#       <td id="T_6b631_row3_col4" class="data row3 col4" >0.0</td>
#       <td id="T_6b631_row3_col5" class="data row3 col5" >0.0</td>
#       <td id="T_6b631_row3_col6" class="data row3 col6" >0.0</td>
#       <td id="T_6b631_row3_col7" class="data row3 col7" >0.0</td>
#       <td id="T_6b631_row3_col8" class="data row3 col8" >0.0</td>
#       <td id="T_6b631_row3_col9" class="data row3 col9" >0.0</td>
#       <td id="T_6b631_row3_col10" class="data row3 col10" >0.0</td>
#     </tr>
#     <tr>
#       <th id="T_6b631_level0_row4" class="row_heading level0 row4" >loc_ic_t2o_mou</th>
#       <td id="T_6b631_row4_col0" class="data row4 col0" >30011.0</td>
#       <td id="T_6b631_row4_col1" class="data row4 col1" >0.0</td>
#       <td id="T_6b631_row4_col2" class="data row4 col2" >0.0</td>
#       <td id="T_6b631_row4_col3" class="data row4 col3" >0.0</td>
#       <td id="T_6b631_row4_col4" class="data row4 col4" >0.0</td>
#       <td id="T_6b631_row4_col5" class="data row4 col5" >0.0</td>
#       <td id="T_6b631_row4_col6" class="data row4 col6" >0.0</td>
#       <td id="T_6b631_row4_col7" class="data row4 col7" >0.0</td>
#       <td id="T_6b631_row4_col8" class="data row4 col8" >0.0</td>
#       <td id="T_6b631_row4_col9" class="data row4 col9" >0.0</td>
#       <td id="T_6b631_row4_col10" class="data row4 col10" >0.0</td>
#     </tr>
#     <tr>
#       <th id="T_6b631_level0_row5" class="row_heading level0 row5" >arpu_6</th>
#       <td id="T_6b631_row5_col0" class="data row5 col0" >30011.0</td>
#       <td id="T_6b631_row5_col1" class="data row5 col1" >587.3</td>
#       <td id="T_6b631_row5_col2" class="data row5 col2" >442.7</td>
#       <td id="T_6b631_row5_col3" class="data row5 col3" >-2258.7</td>
#       <td id="T_6b631_row5_col4" class="data row5 col4" >18.2</td>
#       <td id="T_6b631_row5_col5" class="data row5 col5" >201.9</td>
#       <td id="T_6b631_row5_col6" class="data row5 col6" >495.7</td>
#       <td id="T_6b631_row5_col7" class="data row5 col7" >994.1</td>
#       <td id="T_6b631_row5_col8" class="data row5 col8" >1626.4</td>
#       <td id="T_6b631_row5_col9" class="data row5 col9" >1983.1</td>
#       <td id="T_6b631_row5_col10" class="data row5 col10" >27731.1</td>
#     </tr>
#     <tr>
#       <th id="T_6b631_level0_row6" class="row_heading level0 row6" >arpu_7</th>
#       <td id="T_6b631_row6_col0" class="data row6 col0" >30011.0</td>
#       <td id="T_6b631_row6_col1" class="data row6 col1" >589.1</td>
#       <td id="T_6b631_row6_col2" class="data row6 col2" >462.9</td>
#       <td id="T_6b631_row6_col3" class="data row6 col3" >-2014.0</td>
#       <td id="T_6b631_row6_col4" class="data row6 col4" >25.8</td>
#       <td id="T_6b631_row6_col5" class="data row6 col5" >212.7</td>
#       <td id="T_6b631_row6_col6" class="data row6 col6" >493.6</td>
#       <td id="T_6b631_row6_col7" class="data row6 col7" >995.6</td>
#       <td id="T_6b631_row6_col8" class="data row6 col8" >1644.3</td>
#       <td id="T_6b631_row6_col9" class="data row6 col9" >1999.4</td>
#       <td id="T_6b631_row6_col10" class="data row6 col10" >35145.8</td>
#     </tr>
#     <tr>
#       <th id="T_6b631_level0_row7" class="row_heading level0 row7" >arpu_8</th>
#       <td id="T_6b631_row7_col0" class="data row7 col0" >30011.0</td>
#       <td id="T_6b631_row7_col1" class="data row7 col1" >534.9</td>
#       <td id="T_6b631_row7_col2" class="data row7 col2" >492.3</td>
#       <td id="T_6b631_row7_col3" class="data row7 col3" >-945.8</td>
#       <td id="T_6b631_row7_col4" class="data row7 col4" >0.0</td>
#       <td id="T_6b631_row7_col5" class="data row7 col5" >22.2</td>
#       <td id="T_6b631_row7_col6" class="data row7 col6" >452.1</td>
#       <td id="T_6b631_row7_col7" class="data row7 col7" >985.2</td>
#       <td id="T_6b631_row7_col8" class="data row7 col8" >1662.2</td>
#       <td id="T_6b631_row7_col9" class="data row7 col9" >1987.9</td>
#       <td id="T_6b631_row7_col10" class="data row7 col10" >33543.6</td>
#     </tr>
#     <tr>
#       <th id="T_6b631_level0_row8" class="row_heading level0 row8" >onnet_mou_6</th>
#       <td id="T_6b631_row8_col0" class="data row8 col0" >30011.0</td>
#       <td id="T_6b631_row8_col1" class="data row8 col1" >296.0</td>
#       <td id="T_6b631_row8_col2" class="data row8 col2" >460.8</td>
#       <td id="T_6b631_row8_col3" class="data row8 col3" >0.0</td>
#       <td id="T_6b631_row8_col4" class="data row8 col

# %%
#Outlier handle

#Cap(Winsorization) the Outliers data: Values that are less than the value at 1st percentile are replaced by the value at 1st percentile,
#and values that are greater than the value at 99th percentile are replaced by the value at 99th percentile.

#Columns for Capping
outlierCol = telecomfilter.describe().columns

#Using loop to replace the value with 1st percentile and 99th percentile.
for col in outlierCol[1:]:
    percentiles = telecomfilter[col].quantile([0.01, 0.99]).values
    telecomfilter[col] = np.clip(telecomfilter[col], percentiles[0], percentiles[1])

# %%
#Data after Outliers treatment.
(telecomfilter.describe(percentiles=[0.01,0.05,0.9,0.98,0.99]).T).style.format("{:.1f}")
# Out:
# <style type="text/css">
# </style>
# <table id="T_148cc_">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th class="col_heading level0 col0" >count</th>
#       <th class="col_heading level0 col1" >mean</th>
#       <th class="col_heading level0 col2" >std</th>
#       <th class="col_heading level0 col3" >min</th>
#       <th class="col_heading level0 col4" >1%</th>
#       <th class="col_heading level0 col5" >5%</th>
#       <th class="col_heading level0 col6" >50%</th>
#       <th class="col_heading level0 col7" >90%</th>
#       <th class="col_heading level0 col8" >98%</th>
#       <th class="col_heading level0 col9" >99%</th>
#       <th class="col_heading level0 col10" >max</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_148cc_level0_row0" class="row_heading level0 row0" >mobile_number</th>
#       <td id="T_148cc_row0_col0" class="data row0 col0" >30011.0</td>
#       <td id="T_148cc_row0_col1" class="data row0 col1" >7001222923.6</td>
#       <td id="T_148cc_row0_col2" class="data row0 col2" >684640.5</td>
#       <td id="T_148cc_row0_col3" class="data row0 col3" >7000000074.0</td>
#       <td id="T_148cc_row0_col4" class="data row0 col4" >7000027770.4</td>
#       <td id="T_148cc_row0_col5" class="data row0 col5" >7000137611.0</td>
#       <td id="T_148cc_row0_col6" class="data row0 col6" >7001231966.0</td>
#       <td id="T_148cc_row0_col7" class="data row0 col7" >7002167078.0</td>
#       <td id="T_148cc_row0_col8" class="data row0 col8" >7002363027.4</td>
#       <td id="T_148cc_row0_col9" class="data row0 col9" >7002386671.9</td>
#       <td id="T_148cc_row0_col10" class="data row0 col10" >7002410905.0</td>
#     </tr>
#     <tr>
#       <th id="T_148cc_level0_row1" class="row_heading level0 row1" >circle_id</th>
#       <td id="T_148cc_row1_col0" class="data row1 col0" >30011.0</td>
#       <td id="T_148cc_row1_col1" class="data row1 col1" >109.0</td>
#       <td id="T_148cc_row1_col2" class="data row1 col2" >0.0</td>
#       <td id="T_148cc_row1_col3" class="data row1 col3" >109.0</td>
#       <td id="T_148cc_row1_col4" class="data row1 col4" >109.0</td>
#       <td id="T_148cc_row1_col5" class="data row1 col5" >109.0</td>
#       <td id="T_148cc_row1_col6" class="data row1 col6" >109.0</td>
#       <td id="T_148cc_row1_col7" class="data row1 col7" >109.0</td>
#       <td id="T_148cc_row1_col8" class="data row1 col8" >109.0</td>
#       <td id="T_148cc_row1_col9" class="data row1 col9" >109.0</td>
#       <td id="T_148cc_row1_col10" class="data row1 col10" >109.0</td>
#     </tr>
#     <tr>
#       <th id="T_148cc_level0_row2" class="row_heading level0 row2" >loc_og_t2o_mou</th>
#       <td id="T_148cc_row2_col0" class="data row2 col0" >30011.0</td>
#       <td id="T_148cc_row2_col1" class="data row2 col1" >0.0</td>
#       <td id="T_148cc_row2_col2" class="data row2 col2" >0.0</td>
#       <td id="T_148cc_row2_col3" class="data row2 col3" >0.0</td>
#       <td id="T_148cc_row2_col4" class="data row2 col4" >0.0</td>
#       <td id="T_148cc_row2_col5" class="data row2 col5" >0.0</td>
#       <td id="T_148cc_row2_col6" class="data row2 col6" >0.0</td>
#       <td id="T_148cc_row2_col7" class="data row2 col7" >0.0</td>
#       <td id="T_148cc_row2_col8" class="data row2 col8" >0.0</td>
#       <td id="T_148cc_row2_col9" class="data row2 col9" >0.0</td>
#       <td id="T_148cc_row2_col10" class="data row2 col10" >0.0</td>
#     </tr>
#     <tr>
#       <th id="T_148cc_level0_row3" class="row_heading level0 row3" >std_og_t2o_mou</th>
#       <td id="T_148cc_row3_col0" class="data row3 col0" >30011.0</td>
#       <td id="T_148cc_row3_col1" class="data row3 col1" >0.0</td>
#       <td id="T_148cc_row3_col2" class="data row3 col2" >0.0</td>
#       <td id="T_148cc_row3_col3" class="data row3 col3" >0.0</td>
#       <td id="T_148cc_row3_col4" class="data row3 col4" >0.0</td>
#       <td id="T_148cc_row3_col5" class="data row3 col5" >0.0</td>
#       <td id="T_148cc_row3_col6" class="data row3 col6" >0.0</td>
#       <td id="T_148cc_row3_col7" class="data row3 col7" >0.0</td>
#       <td id="T_148cc_row3_col8" class="data row3 col8" >0.0</td>
#       <td id="T_148cc_row3_col9" class="data row3 col9" >0.0</td>
#       <td id="T_148cc_row3_col10" class="data row3 col10" >0.0</td>
#     </tr>
#     <tr>
#       <th id="T_148cc_level0_row4" class="row_heading level0 row4" >loc_ic_t2o_mou</th>
#       <td id="T_148cc_row4_col0" class="data row4 col0" >30011.0</td>
#       <td id="T_148cc_row4_col1" class="data row4 col1" >0.0</td>
#       <td id="T_148cc_row4_col2" class="data row4 col2" >0.0</td>
#       <td id="T_148cc_row4_col3" class="data row4 col3" >0.0</td>
#       <td id="T_148cc_row4_col4" class="data row4 col4" >0.0</td>
#       <td id="T_148cc_row4_col5" class="data row4 col5" >0.0</td>
#       <td id="T_148cc_row4_col6" class="data row4 col6" >0.0</td>
#       <td id="T_148cc_row4_col7" class="data row4 col7" >0.0</td>
#       <td id="T_148cc_row4_col8" class="data row4 col8" >0.0</td>
#       <td id="T_148cc_row4_col9" class="data row4 col9" >0.0</td>
#       <td id="T_148cc_row4_col10" class="data row4 col10" >0.0</td>
#     </tr>
#     <tr>
#       <th id="T_148cc_level0_row5" class="row_heading level0 row5" >arpu_6</th>
#       <td id="T_148cc_row5_col0" class="data row5 col0" >30011.0</td>
#       <td id="T_148cc_row5_col1" class="data row5 col1" >577.8</td>
#       <td id="T_148cc_row5_col2" class="data row5 col2" >336.0</td>
#       <td id="T_148cc_row5_col3" class="data row5 col3" >18.2</td>
#       <td id="T_148cc_row5_col4" class="data row5 col4" >18.2</td>
#       <td id="T_148cc_row5_col5" class="data row5 col5" >201.9</td>
#       <td id="T_148cc_row5_col6" class="data row5 col6" >495.7</td>
#       <td id="T_148cc_row5_col7" class="data row5 col7" >994.1</td>
#       <td id="T_148cc_row5_col8" class="data row5 col8" >1626.4</td>
#       <td id="T_148cc_row5_col9" class="data row5 col9" >1983.0</td>
#       <td id="T_148cc_row5_col10" class="data row5 col10" >1983.1</td>
#     </tr>
#     <tr>
#       <th id="T_148cc_level0_row6" class="row_heading level0 row6" >arpu_7</th>
#       <td id="T_148cc_row6_col0" class="data row6 col0" >30011.0</td>
#       <td id="T_148cc_row6_col1" class="data row6 col1" >579.7</td>
#       <td id="T_148cc_row6_col2" class="data row6 col2" >338.1</td>
#       <td id="T_148cc_row6_col3" class="data row6 col3" >25.8</td>
#       <td id="T_148cc_row6_col4" class="data row6 col4" >25.8</td>
#       <td id="T_148cc_row6_col5" class="data row6 col5" >212.7</td>
#       <td id="T_148cc_row6_col6" class="data row6 col6" >493.6</td>
#       <td id="T_148cc_row6_col7" class="data row6 col7" >995.6</td>
#       <td id="T_148cc_row6_col8" class="data row6 col8" >1644.3</td>
#       <td id="T_148cc_row6_col9" class="data row6 col9" >1999.3</td>
#       <td id="T_148cc_row6_col10" class="data row6 col10" >1999.4</td>
#     </tr>
#     <tr>
#       <th id="T_148cc_level0_row7" class="row_heading level0 row7" >arpu_8</th>
#       <td id="T_148cc_row7_col0" class="data row7 col0" >30011.0</td>
#       <td id="T_148cc_row7_col1" class="data row7 col1" >524.4</td>
#       <td id="T_148cc_row7_col2" class="data row7 col2" >370.7</td>
#       <td id="T_148cc_row7_col3" class="data row7 col3" >0.0</td>
#       <td id="T_148cc_row7_col4" class="data row7 col4" >0.0</td>
#       <td id="T_148cc_row7_col5" class="data row7 col5" >22.2</td>
#       <td id="T_148cc_row7_col6" class="data row7 col6" >452.1</td>
#       <td id="T_148cc_row7_col7" class="data row7 col7" >985.2</td>
#       <td id="T_148cc_row7_col8" class="data row7 col8" >1662.2</td>
#       <td id="T_148cc_row7_col9" class="data row7 col9" >1987.8</td>
#       <td id="T_148cc_row7_col10" class="data row7 col10" >1987.9</td>
#     </tr>
#     <tr>
#       <th id="T_148cc_level0_row8" class="row_heading level0 row8" >onnet_mou_6</th>
#       <td id="T_148cc_row8_col0" class="data row8 col0" >30011.0</td>
#       <td id="T_148cc_row8_col1" class="data row8 col1" >287.4</td>
#       <td id="T_148cc_row8_col2" class="data row8 col2" >405.0</td>
#       <td id="T_148cc_row8_col3" class="data row8 col3" >0.0</td>
#       <td id="T_148cc_row8_col4" class="data row8 col4" >0.0</td>

# %% [markdown]
# # Data Visualization

# %%
#count plot function
def count_plot(dataframe,col,color=['#063970','#e28743']):
    plt.figure(figsize=(10,5))
    ax=sns.countplot(x=dataframe[col],palette=color)
    totalrow = dataframe.shape[0]
    for p in ax.patches:
        ax.annotate('{:.2f}%'.format(100*p.get_height()/totalrow),(p.get_x()+0.3,p.get_height()+0.01*totalrow),fontweight='bold')
    plt.show()

# %%
#count percentage of customer that churn
count_plot(telecomfilter,'Churn')

# %% [markdown]
# #### Observation: only 8.64% data belong to churn customer

# %%
#Count type of customer
count_plot(telecomfilter,'UserType',color=["#7fcdbb",'#43e259'])

# %% [markdown]
# #### Observation: 47.77% customer only uses Calling Service

# %%
plt.figure(figsize=(10,5))
ax=sns.countplot(x=telecomfilter['UserType'],hue=telecomfilter['Churn'],order=telecomfilter['UserType'].value_counts().index)
for p in ax.patches:
    ax.annotate(p.get_height(),(p.get_x()+0.08,p.get_height()),fontweight='bold')
plt.show()

# %%
telecomfilter.groupby('UserType')['Churn'].value_counts(normalize=True)*100
# Out:
# UserType              Churn
# Both Call & Internet  0        93.627201
#                       1         6.372799
# Calling Service Only  0        88.880363
#                       1        11.119637
# Name: Churn, dtype: float64

# %% [markdown]
# #### Observation: Customer those only uses Calling Service shows approx 11% churn

# %%
#### Visualize calling time of Churn Customer

#Create a dataframe that contains only Churn Customers.
calling = telecomfilter[(telecomfilter['Churn']==1)]
calling.shape
# Out:
# (2593, 153)

# %%
#Create new metrics TotalincomingTime: that store total incoming call time of customer 
calling['TotalincomingTime'] = 0
for i in range(6,9):
    calling['TotalincomingTime'] += calling['total_ic_mou_'+str(i)]

#Create new metrics TotaloutgoingTime: that store total outgoing call time of customer 
calling['TotaloutgoingTime'] = 0
for i in range(6,9):
    calling['TotaloutgoingTime'] +=  calling['total_og_mou_'+str(i)]

# %%
# distplot for the TotalincomingTime and TotaloutgoingTime
plt.figure(figsize=(20,5))
plt.subplot(1, 2, 1)
plt.grid()
ax = sns.distplot(calling['TotalincomingTime'])
plt.subplot(1, 2, 2)
plt.grid()
ax = sns.distplot(calling['TotaloutgoingTime'])
plt.show()

# %%
calling[['TotalincomingTime','TotaloutgoingTime']].describe()
# Out:
#        TotalincomingTime  TotaloutgoingTime
# count        2593.000000        2593.000000
# mean          490.496262        1730.419026
# std           607.220711        1508.659704
# min             0.000000           0.000000
# 25%           129.490000         695.170000
# 50%           293.300000        1399.260000
# 75%           608.590000        2309.170000
# max          5221.127000        9756.826000

# %% [markdown]
# #### Observation: On an average churn customer have higher outgoing call time.

# %%
#### Further observation on outgoing call time

# Create new metrics StdOutTime: that store total STD outgoing call time of customer
calling['StdOutTime'] = 0
for i in range(6,9):
    calling['StdOutTime'] += calling['std_og_mou_'+str(i)]

#Create new metrics LocOutTime: that store total local outgoing call time of customer
calling['LocOutTime'] = 0
for i in range(6,9):
    calling['LocOutTime'] +=  calling['loc_og_mou_'+str(i)]

# %%
calling[['StdOutTime','LocOutTime']].describe()
# Out:
#         StdOutTime   LocOutTime
# count  2593.000000  2593.000000
# mean   1312.900747   374.989161
# std    1431.385691   551.309286
# min       0.000000     0.000000
# 25%      95.500000    60.500000
# 50%     971.060000   173.050000
# 75%    1889.040000   455.920000
# max    8420.011000  4948.153000

# %%
#distplot for StdOutTime and LocOutTime
plt.figure(figsize=(20,5))
plt.subplot(1,2,1)
plt.grid()
ax=sns.distplot(calling['StdOutTime'])
plt.subplot(1,2,2)
plt.grid()
ax=sns.distplot(calling['LocOutTime'])
plt.show()

# %% [markdown]
# #### Observation: Churn customer on an average have higher STD calling time

# %%
#### Visualize Internet uses of Churn Customer

#Create a dataframe that contains only Churn Customers and type of customer that use Both Call & Internet 
internet = telecomfilter[(telecomfilter['UserType']=="Both Call & Internet")]
internet.shape
# Out:
# (15676, 153)

# %%
#uIntType function that categorise the User based on Internet service use.
def uIntType(row):
    if (row['TotalRech-2G'] ==0 and row['TotalRech-3G'] > 0):
        userType= '3GUser'
    elif (row['TotalRech-2G'] >0 and row['TotalRech-3G'] == 0):
         userType= "2GUser"
    elif (row['TotalRech-2G'] >0 and row['TotalRech-3G']> 0):
        userType = "Both 2G-3GUser"
    else:
        userType = "None"
    return userType

internet['InternetUserType']= internet.apply(uIntType,axis=1)

# %%
internet['InternetUserType'].value_counts()
# Out:
# 2GUser            7816
# Both 2G-3GUser    4621
# 3GUser            3239
# Name: InternetUserType, dtype: int64

# %%
internet.groupby('InternetUserType')['Churn'].value_counts(normalize=True)*100
# Out:
# InternetUserType  Churn
# 2GUser            0        93.513306
#                   1         6.486694
# 3GUser            0        91.694968
#                   1         8.305032
# Both 2G-3GUser    0        95.174205
#                   1         4.825795
# Name: Churn, dtype: float64

# %% [markdown]
# #### Observation:  No such difference was found for the internet using type on churn rate

# %% [markdown]
# # Model Building and Evaluation

# %%
# Drop Columns that are not needed

#mobile_number:contains unique mobile number, circle_id: same for all records i.e 109,
#loc_og_t2o_mou,std_og_t2o_mou,loc_ic_t2o_mou : same for all records i.e 0
#last_date_of_month_ : last day of the month
telecommodel = telecomfilter.copy()
telecommodel = telecommodel.drop(['mobile_number','circle_id','loc_og_t2o_mou','std_og_t2o_mou','loc_ic_t2o_mou',
                                   'last_date_of_month_6','last_date_of_month_7','last_date_of_month_8','date_of_last_rech_6',
                                   'date_of_last_rech_7','date_of_last_rech_8'],axis=1)

telecommodel.shape
# Out:
# (30011, 142)

# %%
col = telecommodel.select_dtypes(('object'))
print("Total categorical variables",len(col.columns))

dummyvar = pd.get_dummies(telecommodel[col.columns],drop_first=True)
print("Total dummies variable created",dummyvar.shape[1])

#concat the created dummy variables with the dataset.
telecommodel = pd.concat([dummyvar,telecommodel],axis=1)

#Drop the variables for which dummy variable is created.
telecommodel=telecommodel.drop(col.columns,axis=1)
telecommodel.head()
# Out:
# Total categorical variables 2
# Total dummies variable created 6
#     AON_Y_2-4 Year  AON_Y_4-6 Year  AON_Y_6-8 Year  AON_Y_<1 Year  \
# 7                1               0               0              0
# 8                0               0               0              1
# 13               0               0               1              0
# 16               0               0               0              0
# 17               0               0               0              0
#
#     AON_Y_>8 Year  UserType_Calling Service Only    arpu_6     arpu_7  \
# 7               0                              1  1069.180  1349.8500
# 8               0                              0   378.721   492.2230
# 13              0                              0   492.846   205.6710
# 16              0                              1   430.975   299.8690
# 17              0                              1   690.008    25.7827
#
#        arpu_8  onnet_mou_6  ...  arpu_diff  TotalRech-2G  TotalRech-3G  \
# 7   1987.9344        57.84  ...  864.34085           0.0           0.0
# 8    137.3620       413.69  ... -298.11000           5.0           0.0
# 13   593.2600       501.76  ...  244.00150           3.0           0.0
# 16   187.8940        50.51  ... -177.52800           0.0           0.0
# 17    25.4990      1185.91  ... -328.99500           0.0           0.0
#
#     TotalRech_2G-3G  InternetUser  TotalRech-Call  TotalRech-Call_Amnt  \
# 7               0.0             0            17.0               6008.0
# 8               5.0             1            54.0               1158.0
# 13              3.0             1            21.0               1477.0
# 16              0.0             0            18.0               1078.0
# 17              0.0             0            25.0                846.0
#
#     TotalDataUsed  TotalCallTime  Churn
# 7            0.00          51.00      1
# 8         1118.92          21.01      0
# 13           0.02          73.34      0
# 16           0.00          31.78      0
# 17           0.00          22.41      0
#
# [5 rows x 146 columns]

# %% [markdown]
# #### Test Train Split

# %%
# Putting predictive variable to y
y = telecommodel.pop('Churn')

# Putting feature variable to X
X = telecommodel

# Print shape of X and y
print("X shape " + str(X.shape))
print("y shape " + str(y.shape))
# Out:
# X shape (30011, 145)
# y shape (30011,)

# %%
#Split Train data into 70% and Test data in 30%.
# Use stratify parameter to make a split so that the proportion of values in the sample produced will be the same as the proportion of values provided to parameter
X_train, X_test, y_train, y_test = train_test_split(X,y,train_size=0.7,random_state=42,stratify=y)


# Print shape of X and y
print("X_train shape ",X_train.shape)
print("y_train shape ",y_train.shape)
print("")
print("X_test shape ",X_test.shape)
print("y_test shape ",y_test.shape)
# Out:
# X_train shape  (21007, 145)
# y_train shape  (21007,)
#
# X_test shape  (9004, 145)
# y_test shape  (9004,)

# %% [markdown]
# #### Scaling

# %%
#Use StandardScaler to fit the training set.
#StandardScaler removes the mean and scales each feature/variable to unit variance.
scaler = StandardScaler()
X_train = pd.DataFrame(scaler.fit_transform(X_train),columns = X_train.columns)

# %% [markdown]
# #### Reduce the number of Variables using PCA

# %%
#Fit PCA on the trianing data set.
pca = PCA(random_state=42)
pca.fit(X_train)
# Out:
# PCA(random_state=42)

# %%
pca.explained_variance_ratio_
# Out:
# array([1.13039900e-01, 9.40065219e-02, 6.80409459e-02, 5.06210673e-02,
#        4.41128697e-02, 3.45281148e-02, 3.01598273e-02, 2.75682828e-02,
#        2.64689718e-02, 2.46619843e-02, 2.23542635e-02, 2.18710318e-02,
#        1.94699205e-02, 1.81601861e-02, 1.69466873e-02, 1.60422741e-02,
#        1.49518578e-02, 1.30910974e-02, 1.30359247e-02, 1.25661336e-02,
#        1.11241749e-02, 1.02933583e-02, 1.00412229e-02, 9.81013551e-03,
#        9.74689038e-03, 9.20529691e-03, 8.50479238e-03, 8.29751839e-03,
#        8.13888701e-03, 7.87990184e-03, 7.74093727e-03, 7.65636736e-03,
#        7.31013507e-03, 7.10004540e-03, 6.61351260e-03, 6.47988250e-03,
#        6.40622026e-03, 6.25155760e-03, 5.96545818e-03, 5.87169392e-03,
#        5.39506086e-03, 5.38390583e-03, 5.18134276e-03, 5.05699905e-03,
#        4.96982020e-03, 4.91302480e-03, 4.64774476e-03, 4.46171454e-03,
#        4.29346179e-03, 4.19687417e-03, 4.09020116e-03, 3.95794833e-03,
#        3.80005919e-03, 3.71322392e-03, 3.47033011e-03, 3.45059737e-03,
#        3.32063559e-03, 3.03105713e-03, 2.99687817e-03, 2.93802418e-03,
#        2.89301217e-03, 2.83652912e-03, 2.70392805e-03, 2.62578939e-03,
#        2.54488349e-03, 2.51017548e-03, 2.42352765e-03, 2.32586828e-03,
#        2.27412637e-03, 2.23790317e-03, 2.18009289e-03, 2.14735799e-03,
#        2.14384670e-03, 2.10396507e-03, 2.09674122e-03, 2.06050577e-03,
#        1.99739818e-03, 1.92378989e-03, 1.88310910e-03, 1.78402460e-03,
#        1.65637263e-03, 1.62183039e-03, 1.56093220e-03, 1.49206492e-03,
#        1.46493439e-03, 1.44755175e-03, 1.42000652e-03, 1.40064521e-03,
#        1.35091971e-03, 1.22062697e-03, 1.11667291e-03, 1.09212678e-03,
#        1.05503448e-03, 1.02929099e-03, 9.50898229e-04, 9.08310031e-04,
#        8.41134596e-04, 6.96422881e-04, 6.88400839e-04, 6.50830755e-04,
#        5.73870371e-04, 4.92342932e-04, 4.21786748e-04, 4.04307763e-04,
#        3.60499042e-04, 2.65452973e-04, 2.45788155e-04, 2.36190797e-04,
#        2.15438069e-04, 2.05756681e-04, 1.51867524e-04, 1.47659335e-04,
#        1.25312412e-04, 1.17593421e-04, 1.10152127e-04, 1.09364406e-04,
#        9.84064006e-05, 9.50862946e-05, 9.18052973e-05, 8.69985766e-05,
#        8.42669852e-05, 7.51988875e-05, 6.56022211e-05, 6.13471589e-05,
#        5.25962003e-05, 4.57043607e-05, 4.38169888e-05, 4.17890965e-05,
#        4.04581435e-05, 3.30800045e-05, 2.98176050e-05, 2.97123315e-05,
#        2.69054040e-05, 2.27964879e-05, 1.36757164e-05, 1.12165619e-05,
#        2.22931894e-32, 5.88291793e-34, 5.88291793e-34, 5.88291793e-34,
#        5.88291793e-34, 5.88291793e-34, 5.88291793e-34, 5.88291793e-34,
#        5.88291793e-34])

# %%
#Plot cumulative variance explained vs number of variables.
varcum = np.cumsum(pca.explained_variance_ratio_)
plt.figure(figsize=(10,5))
plt.hlines(y=0.97,xmax=140,xmin=0,colors='r',linestyles="--")
plt.vlines(x=80,ymax=1,ymin=0,colors='g',linestyles="--")
plt.plot(varcum)
plt.ylabel("Cumulative variance explained",fontweight='bold')
plt.xlabel("Number of Components",fontweight='bold')
plt.show()

# %% [markdown]
# #### Observation: 97% of variance explained by 80 components.

# %%
#Reduce dimensionality of trainig dataset using incremental PCA.
pca = IncrementalPCA(n_components=80)
X_train = pca.fit_transform(X_train)

#Shape of training data set after removing variables
X_train.shape
# Out:
# (21007, 80)

# %% [markdown]
# ### Logistic Regression Model

# %%
#Instantiate a Logistic Regression Moldel.
lr = LogisticRegression(random_state=42,class_weight={1:0.9,0:0.1})

# %%
#Hyperparameter tuning for Logistic Regression
logparams = {'penalty': ['l1', 'l2'],
             'C': [0.01, 0.1, 1, 10, 100]}
            

model_logregression = GridSearchCV(estimator=lr, param_grid=logparams, cv=4, n_jobs=-1,verbose=1,scoring="recall")

# %%
# %%time
#Fit the model on the training dataset.
model_logregression.fit(X_train,y_train)
# Out:
# Fitting 4 folds for each of 10 candidates, totalling 40 fits
# Wall time: 29.2 s
# GridSearchCV(cv=4,
#              estimator=LogisticRegression(class_weight={0: 0.1, 1: 0.9},
#                                           random_state=42),
#              n_jobs=-1,
#              param_grid={'C': [0.01, 0.1, 1, 10, 100], 'penalty': ['l1', 'l2']},
#              scoring='recall', verbose=1)

# %%
#Best estimator values for Decision Tree classifier model.
model_logregression.best_estimator_
# Out:
# LogisticRegression(C=10, class_weight={0: 0.1, 1: 0.9}, random_state=42)

# %%
#RandomForest model with best hyper parameter value.
model_logregressionbest = model_logregression.best_estimator_

#Predict y on the train data
y_train_Logpred = model_logregressionbest.predict(X_train)

# %%
#Accuracy on train data set.
metrics.accuracy_score(y_train,y_train_Logpred)
# Out:
# 0.8434331413338411

# %%
#Confusion Matrix
metrics.confusion_matrix(y_train,y_train_Logpred)
# Out:
# array([[16219,  2973],
#        [  316,  1499]], dtype=int64)

# %%
#classification report for the Decision Tree Classifier model.
print(metrics.classification_report(y_train,y_train_Logpred))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.98      0.85      0.91     19192
#            1       0.34      0.83      0.48      1815
#
#     accuracy                           0.84     21007
#    macro avg       0.66      0.84      0.69     21007
# weighted avg       0.93      0.84      0.87     21007

# %% [markdown]
# ### Decision Tree Classifier Model

# %%
#Instantiate Decision Tree Classifier
dt = DecisionTreeClassifier(random_state=42,class_weight={1:0.9,0:0.1})

# %%
#Hyperparameter tuninig for Decision Tree classifier model.
dtparams = { 
          'max_depth': [3,5,10],
          'min_samples_leaf': [50,100,200,500],
          'min_samples_split': [50,75,100],
          'criterion':['gini','entropy'],
          'max_features': ['auto','sqrt','log2']}

model_decisiontree = GridSearchCV(estimator=dt, param_grid=dtparams, cv=4, n_jobs=-1,verbose=1,scoring="recall")

# %%
# %%time
#Fit the model on the training dataset.
model_decisiontree.fit(X_train,y_train)
# Out:
# Fitting 4 folds for each of 216 candidates, totalling 864 fits
# Wall time: 57.9 s
# GridSearchCV(cv=4,
#              estimator=DecisionTreeClassifier(class_weight={0: 0.1, 1: 0.9},
#                                               random_state=42),
#              n_jobs=-1,
#              param_grid={'criterion': ['gini', 'entropy'],
#                          'max_depth': [3, 5, 10],
#                          'max_features': ['auto', 'sqrt', 'log2'],
#                          'min_samples_leaf': [50, 100, 200, 500],
#                          'min_samples_split': [50, 75, 100]},
#              scoring='recall', verbose=1)

# %%
#Best estimator values for Decision Tree classifier model.
model_decisiontree.best_estimator_
# Out:
# DecisionTreeClassifier(class_weight={0: 0.1, 1: 0.9}, criterion='entropy',
#                        max_depth=5, max_features='auto', min_samples_leaf=200,
#                        min_samples_split=50, random_state=42)

# %%
#DecisionTree model with best hyper parameter value.
model_decisiontreebest = model_decisiontree.best_estimator_

#predict the target variable.
y_train_dtpred = model_decisiontreebest.predict(X_train)

# %%
#Accuracy on train data set.
metrics.accuracy_score(y_train,y_train_dtpred)
# Out:
# 0.7777883562621983

# %%
#Confusion Matrix
metrics.confusion_matrix(y_train,y_train_dtpred)
# Out:
# array([[14967,  4225],
#        [  443,  1372]], dtype=int64)

# %%
#classification report for the Decision Tree Classifier model.
print(metrics.classification_report(y_train,y_train_dtpred))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.97      0.78      0.87     19192
#            1       0.25      0.76      0.37      1815
#
#     accuracy                           0.78     21007
#    macro avg       0.61      0.77      0.62     21007
# weighted avg       0.91      0.78      0.82     21007

# %% [markdown]
# ### Random Forest Classifier Model

# %%
#Instantiate Random Forest classifier.
rf = RandomForestClassifier(random_state=42,class_weight={1:0.9,0:0.1})

# %%
#Hyperparameter tuning for Random Forest classifier Model.
rfparams = {'n_estimators': [10,25,50,100,200],
            'max_depth': [3,5,10],
            'min_samples_leaf': [20,50,100,200],
            'max_features': ['auto', 'sqrt']}

model_randomforest = GridSearchCV(estimator=rf,param_grid=rfparams,cv=4,verbose=1,n_jobs=-1,scoring="recall")

# %%
# %%time
#Fit the model on the training dataset.
model_randomforest.fit(X_train,y_train)
# Out:
# Fitting 4 folds for each of 120 candidates, totalling 480 fits
# Wall time: 15min 14s
# GridSearchCV(cv=4,
#              estimator=RandomForestClassifier(class_weight={0: 0.1, 1: 0.9},
#                                               random_state=42),
#              n_jobs=-1,
#              param_grid={'max_depth': [3, 5, 10],
#                          'max_features': ['auto', 'sqrt'],
#                          'min_samples_leaf': [20, 50, 100, 200],
#                          'n_estimators': [10, 25, 50, 100, 200]},
#              scoring='recall', verbose=1)

# %%
#Random Forest best estimators.
model_randomforest.best_estimator_
# Out:
# RandomForestClassifier(class_weight={0: 0.1, 1: 0.9}, max_depth=10,
#                        min_samples_leaf=200, n_estimators=200, random_state=42)

# %%
#RandomForest model with best hyper parameter value.
model_randomforestbest = model_randomforest.best_estimator_

#predict the target variable.
y_train_rfpred =model_randomforestbest.predict(X_train)

# %%
#Print accuracy of the model.
print(metrics.accuracy_score(y_train,y_train_rfpred))
# Out:
# 0.8865616223163707

# %%
#Classification Report for Random Forest classifier Model.
print(metrics.classification_report(y_train,y_train_rfpred))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.98      0.90      0.94     19192
#            1       0.42      0.77      0.54      1815
#
#     accuracy                           0.89     21007
#    macro avg       0.70      0.83      0.74     21007
# weighted avg       0.93      0.89      0.90     21007

# %% [markdown]
# ## KNN Model

# %%
knn = KNeighborsClassifier()

# %%
#Hyperparameter tuning for Random Forest classifier Model.
knnparams =  {
             'n_neighbors': [10,20,50,100],
              'leaf_size':[40,50,100],
             'weights': ['uniform','distance']}

model_knn = GridSearchCV(estimator=knn,param_grid=knnparams,cv=4,verbose=1,n_jobs=-1,scoring="recall")

# %%
# %%time
model_knn.fit(X_train,y_train)
# Out:
# Fitting 4 folds for each of 24 candidates, totalling 96 fits
# Wall time: 14min
# GridSearchCV(cv=4, estimator=KNeighborsClassifier(), n_jobs=-1,
#              param_grid={'leaf_size': [40, 50, 100],
#                          'n_neighbors': [10, 20, 50, 100],
#                          'weights': ['uniform', 'distance']},
#              scoring='recall', verbose=1)

# %%
#KNN model best estimators.
model_knn.best_estimator_
# Out:
# KNeighborsClassifier(leaf_size=40, n_neighbors=10, weights='distance')

# %%
#KNN model with best hyper parameter value.
model_knnbest = model_knn.best_estimator_

#predict the target variable.
y_train_knnpred = model_knn.predict(X_train)

# %%
#Print accuracy of the model.
print(metrics.accuracy_score(y_train,y_train_knnpred))
# Out:
# 1.0

# %%
#Confusion Matrix
metrics.confusion_matrix(y_train,y_train_knnpred)
# Out:
# array([[19192,     0],
#        [    0,  1815]], dtype=int64)

# %%
#Classification Report for Random Forest classifier Model.
print(metrics.classification_report(y_train,y_train_knnpred))
# Out:
#               precision    recall  f1-score   support
#
#            0       1.00      1.00      1.00     19192
#            1       1.00      1.00      1.00      1815
#
#     accuracy                           1.00     21007
#    macro avg       1.00      1.00      1.00     21007
# weighted avg       1.00      1.00      1.00     21007

# %% [markdown]
# ## Model Evaluation

# %%
#function to evaluate model on the test data set.
def evaluateModel(model,modelName=None):
    print("\n"+'\033[1m'+str(modelName)+" Test Accuracy Score:"+'\033[0m', 
        round(metrics.accuracy_score(y_test, model.predict(X_test)),2)*100)
    print("\n"+'\033[1m'+str(modelName)+" Test Confusion Matrix:"+'\033[0m')
    cm = metrics.confusion_matrix(y_test, model.predict(X_test))
    plot_confusion_matrix(cm)
    print("\n"+'\033[1m'+str(modelName)+" Test Classification Report:"+'\033[0m')
    print(metrics.classification_report(y_test,model.predict(X_test)))
    print("*"*70)
    print('\033[1m'+"\n ROC CURVE"+'\033[0m')
    metrics.plot_roc_curve(model,X_test,y_test,drop_intermediate=False)
    plt.show()

#Function for Confusion matrix
def plot_confusion_matrix(cm,
                          title='Confusion matrix',
                          cmap=plt.cm.Blues):
    plt.imshow(cm, interpolation='nearest', cmap=cmap)
    plt.title(title)
    plt.colorbar()
    tick_marks = np.arange(len(['Not Churn','Churn']))
    plt.xticks(tick_marks, ['Not Churn','Churn'], rotation=45)
    plt.yticks(tick_marks, ['Not Churn','Churn'])

    thresh = cm.max() / 2.
    for i in range (cm.shape[0]):
        for j in range (cm.shape[1]):
            plt.text(j, i, cm[i, j],
                 horizontalalignment="center",
                 color="white" if cm[i, j] > thresh else "black")

    plt.tight_layout()
    plt.ylabel('True label')
    plt.xlabel('Predicted label')

# %% [markdown]
# #### Scaling

# %%
#Scaling of teatdata set.
X_test = pd.DataFrame(scaler.transform(X_test),columns = X_test.columns)

# %% [markdown]
# #### PCA

# %%
#PCA on Testdata set.
X_test = pca.transform(X_test)

#Shape of Testdata set after PCA.
X_test.shape
# Out:
# (9004, 80)

# %% [markdown]
# ### Model Evaluation :  Logistic Regression

# %%
evaluateModel(model_logregressionbest,"Logistic Regression Model")
# Out:
# Logistic Regression Model Test Accuracy Score: 83.0
#
# Logistic Regression Model Test Confusion Matrix:
#
# Logistic Regression Model Test Classification Report:
#               precision    recall  f1-score   support
#
#            0       0.98      0.84      0.90      8226
#            1       0.32      0.80      0.46       778
#
#     accuracy                           0.83      9004
#    macro avg       0.65      0.82      0.68      9004
# weighted avg       0.92      0.83      0.86      9004
#
# **********************************************************************
#
#  ROC CURVE

# %% [markdown]
# ### Model Evaluation: Decision Tree Classifier

# %%
evaluateModel(model_decisiontreebest,"Decision Tree Classifier Model")
# Out:
# Decision Tree Classifier Model Test Accuracy Score: 77.0
#
# Decision Tree Classifier Model Test Confusion Matrix:
#
# Decision Tree Classifier Model Test Classification Report:
#               precision    recall  f1-score   support
#
#            0       0.97      0.77      0.86      8226
#            1       0.23      0.71      0.35       778
#
#     accuracy                           0.77      9004
#    macro avg       0.60      0.74      0.60      9004
# weighted avg       0.90      0.77      0.81      9004
#
# **********************************************************************
#
#  ROC CURVE

# %% [markdown]
# ### Model Evaluation: Random Forest Classifier

# %%
evaluateModel(model_randomforestbest,"Random Forest Classifier Model")
# Out:
# Random Forest Classifier Model Test Accuracy Score: 88.0
#
# Random Forest Classifier Model Test Confusion Matrix:
#
# Random Forest Classifier Model Test Classification Report:
#               precision    recall  f1-score   support
#
#            0       0.97      0.90      0.93      8226
#            1       0.39      0.72      0.51       778
#
#     accuracy                           0.88      9004
#    macro avg       0.68      0.81      0.72      9004
# weighted avg       0.92      0.88      0.90      9004
#
# **********************************************************************
#
#  ROC CURVE

# %% [markdown]
# ### Model Evaluation KNN Classification Model

# %%
evaluateModel(model_knnbest,"KNN Classification Model")
# Out:
# KNN Classification Model Test Accuracy Score: 92.0
#
# KNN Classification Model Test Confusion Matrix:
#
# KNN Classification Model Test Classification Report:
#               precision    recall  f1-score   support
#
#            0       0.94      0.98      0.96      8226
#            1       0.59      0.31      0.41       778
#
#     accuracy                           0.92      9004
#    macro avg       0.76      0.65      0.68      9004
# weighted avg       0.91      0.92      0.91      9004
#
# **********************************************************************
#
#  ROC CURVE

# %%
#Function return metrics score of the model. 
def modelEvaluation(model,Model_Name):
    score = []
    
    score.append(metrics.recall_score(y_train,model.predict(X_train)))
    score.append(metrics.recall_score(y_test,model.predict(X_test)))
    
    score.append(metrics.roc_auc_score(y_train,model.predict(X_train)))
    score.append(metrics.roc_auc_score(y_test,model.predict(X_test)))
    
    score.append(metrics.f1_score(y_train,model.predict(X_train)))
    score.append(metrics.f1_score(y_test,model.predict(X_test)))
   
    score.append(metrics.accuracy_score(y_train,model.predict(X_train)))
    score.append(metrics.accuracy_score(y_test,model.predict(X_test)))
    
    return pd.Series(score,name=Model_Name)


#Function which returrn table that contains metrics of the models.
def finalScoreMetrics(models):
    score_table = {'Metrics' : ['Recall Score (Train)','Recall Score (Test)','ROC-AUC Score (Train)','ROC-AUC Score (Test)',
                        'F1 Score (Train)', 'F1 Score (Test)', 'Accuracy Score (Train)','Accuracy Score (Test)']}
    score_metrics = pd.DataFrame(score_table,columns=['Metrics'])
    models.insert(0,score_metrics)
    score_metrics = pd.concat([x for x in models],axis=1)
    return score_metrics  


#Function to compare ROC for all the models.
def pltroc(models):
    ax = plt.gca()
    for i in models:
        metrics.plot_roc_curve(i, X_test, y_test, ax=ax)   
    plt.plot([0,1],[0,1], 'k--')
    plt.legend(bbox_to_anchor=(1.0, 1.0))
    plt.title("ROC curve comparison",fontweight="bold")
    plt.show()

# %%
LOGISTIC = modelEvaluation(model_logregressionbest,"Logistic Regression Model")
DECISIONTREE = modelEvaluation(model_decisiontreebest,"Decision Tree Model")
RANDOMFOREST = modelEvaluation(model_randomforestbest,"Random Forest Model")
KNN =  modelEvaluation(model_knnbest,"KNNModel")

# %%
#ROC Comparision for all the models.
pltroc([model_logregressionbest,model_decisiontreebest,model_randomforestbest,model_knnbest])

# %%
#Score Metrics for all the models.
finalScoreMetrics([LOGISTIC,DECISIONTREE,RANDOMFOREST,KNN])
# Out:
#                   Metrics  Logistic Regression Model  Decision Tree Model  \
# 0    Recall Score (Train)                   0.825895             0.755923
# 1     Recall Score (Test)                   0.800771             0.713368
# 2   ROC-AUC Score (Train)                   0.835494             0.767890
# 3    ROC-AUC Score (Test)                   0.819301             0.743020
# 4        F1 Score (Train)                   0.476857             0.370210
# 5         F1 Score (Test)                   0.455576             0.346550
# 6  Accuracy Score (Train)                   0.843433             0.777788
# 7   Accuracy Score (Test)                   0.834629             0.767548
#
#    Random Forest Model  KNNModel
# 0             0.768595  1.000000
# 1             0.719794  0.311054
# 2             0.833156  1.000000
# 3             0.807745  0.645133
# 4             0.539339  1.000000
# 5             0.510018  0.406381
# 6             0.886562  1.000000
# 7             0.880498  0.921479

# %% [markdown]
# __Conclusion :__

# %% [markdown]
# ## Model: To identify important variables that are strong predictors of churn

# %% [markdown]
# - Using Decision to identify the important variables

# %%
#Dataset
telecom_model_2 = telecomfilter.copy()
telecom_model_2.head()
# Out:
#     mobile_number  circle_id  loc_og_t2o_mou  std_og_t2o_mou  loc_ic_t2o_mou  \
# 7      7000701601        109             0.0             0.0             0.0
# 8      7001524846        109             0.0             0.0             0.0
# 13     7002191713        109             0.0             0.0             0.0
# 16     7000875565        109             0.0             0.0             0.0
# 17     7000187447        109             0.0             0.0             0.0
#
#    last_date_of_month_6 last_date_of_month_7 last_date_of_month_8    arpu_6  \
# 7            2014-06-30  2014-07-31 00:00:00  2014-08-31 00:00:00  1069.180
# 8            2014-06-30  2014-07-31 00:00:00  2014-08-31 00:00:00   378.721
# 13           2014-06-30  2014-07-31 00:00:00  2014-08-31 00:00:00   492.846
# 16           2014-06-30  2014-07-31 00:00:00  2014-08-31 00:00:00   430.975
# 17           2014-06-30  2014-07-31 00:00:00  2014-08-31 00:00:00   690.008
#
#        arpu_7  ...  TotalRech-2G  TotalRech-3G  TotalRech_2G-3G  InternetUser  \
# 7   1349.8500  ...           0.0           0.0              0.0             0
# 8    492.2230  ...           5.0           0.0              5.0             1
# 13   205.6710  ...           3.0           0.0              3.0             1
# 16   299.8690  ...           0.0           0.0              0.0             0
# 17    25.7827  ...           0.0           0.0              0.0             0
#
#     TotalRech-Call  TotalRech-Call_Amnt              UserType  TotalDataUsed  \
# 7             17.0               6008.0  Calling Service Only           0.00
# 8             54.0               1158.0  Both Call & Internet        1118.92
# 13            21.0               1477.0  Both Call & Internet           0.02
# 16            18.0               1078.0  Calling Service Only           0.00
# 17            25.0                846.0  Calling Service Only           0.00
#
#     TotalCallTime  Churn
# 7           51.00      1
# 8           21.01      0
# 13          73.34      0
# 16          31.78      0
# 17          22.41      0
#
# [5 rows x 153 columns]

# %%
#Drop the columns that are not required.
telecom_model_2 = telecom_model_2.drop(['mobile_number','circle_id','loc_og_t2o_mou','std_og_t2o_mou','loc_ic_t2o_mou',
                                   'last_date_of_month_6','last_date_of_month_7','last_date_of_month_8','date_of_last_rech_6',
                                   'date_of_last_rech_7','date_of_last_rech_8'],axis=1)

telecom_model_2.shape
# Out:
# (30011, 142)

# %%
#Dummy Variable creation

col = telecom_model_2.select_dtypes(('object'))
print("Total categorical variables",len(col.columns))

dummyvar = pd.get_dummies(telecom_model_2[col.columns],drop_first=True)
print("Total dummies variable created",dummyvar.shape[1])

#concat the created dummy variables with the dataset.
telecom_model_2 = pd.concat([dummyvar,telecom_model_2],axis=1)

#Drop the variables for which dummy variable is created.
telecom_model_2=telecom_model_2.drop(col.columns,axis=1)
telecom_model_2.head()
# Out:
# Total categorical variables 2
# Total dummies variable created 6
#     AON_Y_2-4 Year  AON_Y_4-6 Year  AON_Y_6-8 Year  AON_Y_<1 Year  \
# 7                1               0               0              0
# 8                0               0               0              1
# 13               0               0               1              0
# 16               0               0               0              0
# 17               0               0               0              0
#
#     AON_Y_>8 Year  UserType_Calling Service Only    arpu_6     arpu_7  \
# 7               0                              1  1069.180  1349.8500
# 8               0                              0   378.721   492.2230
# 13              0                              0   492.846   205.6710
# 16              0                              1   430.975   299.8690
# 17              0                              1   690.008    25.7827
#
#        arpu_8  onnet_mou_6  ...  arpu_diff  TotalRech-2G  TotalRech-3G  \
# 7   1987.9344        57.84  ...  864.34085           0.0           0.0
# 8    137.3620       413.69  ... -298.11000           5.0           0.0
# 13   593.2600       501.76  ...  244.00150           3.0           0.0
# 16   187.8940        50.51  ... -177.52800           0.0           0.0
# 17    25.4990      1185.91  ... -328.99500           0.0           0.0
#
#     TotalRech_2G-3G  InternetUser  TotalRech-Call  TotalRech-Call_Amnt  \
# 7               0.0             0            17.0               6008.0
# 8               5.0             1            54.0               1158.0
# 13              3.0             1            21.0               1477.0
# 16              0.0             0            18.0               1078.0
# 17              0.0             0            25.0                846.0
#
#     TotalDataUsed  TotalCallTime  Churn
# 7            0.00          51.00      1
# 8         1118.92          21.01      0
# 13           0.02          73.34      0
# 16           0.00          31.78      0
# 17           0.00          22.41      0
#
# [5 rows x 146 columns]

# %% [markdown]
# ### Test Train Split

# %%
# Putting feature variable to X
X = telecom_model_2.drop(['Churn'], axis=1)

# Putting response variable to y
y = telecom_model_2['Churn']

# %%
#Splitting the data into test and train
X_train_m2,X_test_m2,y_train_m2,y_test_m2 = train_test_split(X,y,test_size=0.3,stratify=y,random_state=42)

# Print shape of X and y
print("X_train_m2 shape ",X_train_m2.shape)
print("y_train_m2 shape ",y_train_m2.shape)
print("")
print("X_test shape_m2 ",X_test_m2.shape)
print("y_test shape_m2 ",y_test_m2.shape)
# Out:
# X_train_m2 shape  (21007, 145)
# y_train_m2 shape  (21007,)
#
# X_test shape_m2  (9004, 145)
# y_test shape_m2  (9004,)

# %%
#Import library that are used to display the Decision Tree.
from IPython.display import Image  
from six import StringIO 
from sklearn.tree import export_graphviz
import pydotplus,graphviz

# %%
#PATH configuration to run graphviz
import os
os.environ['PATH']=os.environ['PATH']+';'+os.environ['CONDA_PREFIX']+r"\Library\bin\graphviz"

# %%
#Function that return decision tree.
def get_dt_graph(dt_classifier):
    dot_data = StringIO()
    export_graphviz(dt_classifier, out_file=dot_data, filled=True,rounded=True,
                    feature_names=X.columns, 
                    class_names=['Non Churn','Churn'])
    graph = pydotplus.graph_from_dot_data(dot_data.getvalue())
    return graph

# %%
#Instantiate Decision Tree Classifier
model2dt = DecisionTreeClassifier(random_state=42,class_weight={1:0.9,0:0.1})

# %%
#Hyperparameter tuninig for Decision Tree classifier model.
model2dtparams = { 
          'max_depth': [3,5,10],
          'min_samples_leaf': [50,100,200,500],
          'min_samples_split': [50,75,100],
          'criterion':['gini','entropy'],
          'max_features': ['auto','sqrt','log2']}

model2_decisiontree = GridSearchCV(estimator=model2dt, param_grid=model2dtparams, cv=4, n_jobs=-1,verbose=1,scoring="recall")

# %%
# %%time
#Fit the model on the training dataset.
model2_decisiontree.fit(X_train_m2,y_train_m2)
# Out:
# Fitting 4 folds for each of 216 candidates, totalling 864 fits
# Wall time: 56.9 s
# GridSearchCV(cv=4,
#              estimator=DecisionTreeClassifier(class_weight={0: 0.1, 1: 0.9},
#                                               random_state=42),
#              n_jobs=-1,
#              param_grid={'criterion': ['gini', 'entropy'],
#                          'max_depth': [3, 5, 10],
#                          'max_features': ['auto', 'sqrt', 'log2'],
#                          'min_samples_leaf': [50, 100, 200, 500],
#                          'min_samples_split': [50, 75, 100]},
#              scoring='recall', verbose=1)

# %%
#DecisionTree model with best hyper parameter value.
model2_dt_best = model2_decisiontree.best_estimator_

#predict the target variable.
y_train_dtpred_model2 = model2_dt_best.predict(X_train_m2)

# %%
#Classification Report
print(metrics.classification_report(y_train_m2,y_train_dtpred_model2))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.98      0.82      0.90     19192
#            1       0.31      0.83      0.45      1815
#
#     accuracy                           0.82     21007
#    macro avg       0.64      0.82      0.67     21007
# weighted avg       0.92      0.82      0.86     21007

# %%
#Decision Tree for the best estimator.
gph = get_dt_graph(model2_dt_best)
Image(gph.create_png())

# %%
#Series that contains top 23 important features.
feature_scores = pd.Series(model2_dt_best.feature_importances_, index=X_train_m2.columns).sort_values(ascending=False).nlargest(23)
feature_scores
# Out:
# loc_ic_t2t_mou_8       0.570100
# roam_og_mou_8          0.144703
# total_rech_amt_8       0.077439
# arpu_diff              0.060959
# vol_3g_mb_8            0.029290
# std_og_mou_7           0.016761
# offnet_mou_8           0.014231
# total_ic_mou_6         0.013255
# loc_og_mou_8           0.011908
# arpu_8                 0.011896
# total_rech_amt_7       0.010602
# loc_ic_t2f_mou_7       0.004996
# spl_og_mou_7           0.004632
# loc_og_t2m_mou_6       0.004571
# onnet_mou_6            0.004069
# total_og_mou_8         0.003098
# vol_2g_mb_8            0.002653
# onnet_mou_7            0.002617
# last_day_rch_amt_7     0.002447
# vol_2g_mb_6            0.002387
# TotalRech-Call_Amnt    0.002210
# loc_og_mou_7           0.002053
# aon                    0.001955
# dtype: float64

# %%
#Visualize top features.
ax = plt.subplots(figsize=(10,5))
ax = sns.barplot(x=feature_scores,y=feature_scores.index)
ax.set_title("Visualize Feature Importance")
ax.set_yticklabels(feature_scores.index)
ax.set_xlabel("Feature Importance Score")
ax.set_ylabel("Features")
plt.show()

# %% [markdown]
# ## Strategies to manage customer churn.
# - Provide cheap Roaming plans to the customers.
# - Provide cheap STD plans to the customers.
# - Provide 3G Internet pack with more MB at low cost.

# %% [markdown]
# # Feature Importance using Logistic Regression

# %% [markdown]
# ### Feature Scaling

# %%
#Use StandardScaler to fit the training set.
#StandardScaler removes the mean and scales each feature/variable to unit variance.
scaler_m2 = StandardScaler()
X_train_m2 = pd.DataFrame(scaler_m2.fit_transform(X_train_m2),columns=X_train_m2.columns)

# %% [markdown]
# ### Correlation Check

# %%
#Function to return variables correlation that are above the given threshold
def absHighPass(df, absThresh):
    passed = set()
    for (r,c) in combinations(df.columns, 2):
        if (abs(df.loc[r,c]) >= absThresh):
            passed.add(r)
            passed.add(c)
    passed = sorted(passed)
    return df.loc[passed,passed]

#Plot heat map (threshold above 90)
plt.figure(figsize=(20,15))
sns.heatmap(absHighPass(telecom_model_2.corr(),0.9),annot=True,cmap="YlGnBu")
plt.show()

# %% [markdown]
# #### Observation:
# - UserType_CallingServiceOnly and Internet User are 100% negatively correlated.
# - arpu_6 and total_rech_amt_6 are 93% positively correlated.
# - arpu_7 and total_rech_amt_7 are 92% positively correlated.
# - arpu_8 and total_rech_amt_8 are 94% positively correlated.
# - total_ic_mou_6 and loc_ic_mou_6 are 90% positively correlated.
# - total_ic_mou_8 and loc_ic_mou_8 are 90% positively correlated.
# - TotalRech-call and total_rech_num_7 are 92% positively correlated.

# %%
#Dropping Highly correlated variables for training and test set.
X_train_m2 = X_train_m2.drop(columns=['InternetUser','total_rech_amt_6','total_rech_amt_7','total_rech_amt_8',
                                     'loc_ic_mou_6','loc_ic_mou_8','total_rech_num_7'],axis=1)
print("X_train_m2 shape ",X_train_m2.shape)

X_test_m2 = X_test_m2.drop(columns=['InternetUser','total_rech_amt_6','total_rech_amt_7','total_rech_amt_8',
                                     'loc_ic_mou_6','loc_ic_mou_8','total_rech_num_7'],axis=1)

print("\n X_test_m2 shape ",X_train_m2.shape)
# Out:
# X_train_m2 shape  (21007, 138)
#
#  X_test_m2 shape  (21007, 138)

# %% [markdown]
# ### Feature Selection using RFE

# %%
X_train_m2.shape
# Out:
# (21007, 138)

# %%
#There are total 138 variables select top 50 variables using RFE
lm = LogisticRegression(class_weight={1:0.9,0:0.1})
lm.fit(X_train_m2,y_train_m2)
rfe = RFE(lm,15)
rfe.fit(X_train_m2,y_train_m2)
# Out:
# RFE(estimator=LogisticRegression(class_weight={0: 0.1, 1: 0.9}),
#     n_features_to_select=15)

# %%
#Creating dataframe with RFE selected variables
RFEcol = X_train_m2.columns[rfe.support_]
X_train_m2_RFE = X_train_m2[RFEcol]
pd.set_option('display.max_columns', None)
X_train_m2_RFE.head()
# Out:
#    onnet_mou_7  offnet_mou_7  loc_og_t2t_mou_8  loc_og_t2m_mou_7  \
# 0     0.016681      4.637253          0.147718          0.023791
# 1     1.852891      2.311864         -0.305911         -0.075256
# 2     1.747521     -0.853173         -0.529870         -0.667583
# 3    -0.510480     -0.640894         -0.351804         -0.422281
# 4    -0.679675     -0.316257         -0.460248          0.071093
#
#    std_og_t2t_mou_7  std_og_t2m_mou_7  loc_ic_t2m_mou_7  loc_ic_t2m_mou_8  \
# 0          0.103270          5.092155         -0.506149         -0.699630
# 1          2.279659          2.778880         -0.151340         -0.476317
# 2          2.261735         -0.514056         -0.752096         -0.717453
# 3         -0.390574         -0.463617         -0.168195         -0.530796
# 4         -0.514571         -0.542943          0.021249         -0.193746
#
#    total_ic_mou_8  spl_ic_mou_8  total_rech_num_8  last_day_rch_amt_8  \
# 0       -0.421490      2.235067         -0.243025           -0.825762
# 1       -0.226566      2.235067         -0.013122            0.473714
# 2       -0.314479     -0.256075         -0.357977            0.202990
# 3       -0.427803     -0.256075         -0.357977           -0.825762
# 4       -0.474049     -0.256075         -0.817784            4.760179
#
#    monthly_2g_8  monthly_3g_8  arpu_diff
# 0     -0.323328     -0.324391  -3.140666
# 1     -0.323328     -0.324391   0.501357
# 2     -0.323328     -0.324391  -1.496857
# 3     -0.323328     -0.324391  -0.258664
# 4     -0.323328      1.644543   0.007469

# %%
import statsmodels.api as sm

# %%
# function to build model and calculate VIF of the selected variables
def build_model(train_df):
    X_train_sm = sm.add_constant(train_df) # add constant to the dataset.
    model_2 = sm.GLM(y_train_m2.values.reshape(-1,1),X_train_sm, family = sm.families.Binomial())  #create a model
    model_2 = model_2.fit()                #fit the model
    print(model_2.summary())
    
    #calculate VIF of the variables present in the dataset
    print("---------VIF-----------")
    vif = pd.DataFrame()
    vif['Features']=train_df.columns
    vif['VIF'] = [variance_inflation_factor(train_df.values,i) for i in range (train_df.shape[1])]
    vif['VIF'] = round(vif['VIF'],2)
    vif = vif.sort_values(by = "VIF",ascending = False)
    print(vif)

# %%
#build model with RFE selected variables.
build_model(X_train_m2_RFE)
# Out:
#                  Generalized Linear Model Regression Results
# ==============================================================================
# Dep. Variable:                      y   No. Observations:                21007
# Model:                            GLM   Df Residuals:                    20991
# Model Family:                Binomial   Df Model:                           15
# Link Function:                  logit   Scale:                          1.0000
# Method:                          IRLS   Log-Likelihood:                -4082.3
# Date:                Sat, 21 Aug 2021   Deviance:                       8164.6
# Time:                        16:39:27   Pearson chi2:                 4.38e+05
# No. Iterations:                     8
# Covariance Type:            nonrobust
# ======================================================================================
#                          coef    std err          z      P>|z|      [0.025      0.975]
# --------------------------------------------------------------------------------------
# const                 -4.0827      0.070    -58.106      0.000      -4.220      -3.945
# onnet_mou_7            0.4797      0.109      4.404      0.000       0.266       0.693
# offnet_mou_7           1.0722      0.112      9.570      0.000       0.853       1.292
# loc_og_t2t_mou_8      -0.5838      0.103     -5.649      0.000      -0.786      -0.381
# loc_og_t2m_mou_7      -0.8739      0.081    -10.800      0.000      -1.033      -0.715
# std_og_t2t_mou_7      -0.4400      0.102     -4.320      0.000      -0.640      -0.240
# std_og_t2m_mou_7      -0.9090      0.102     -8.891      0.000      -1.109      -0.709
# loc_ic_t2m_mou_7       0.6721      0.070      9.622      0.000       0.535       0.809
# loc_ic_t2m_mou_8      -1.2552      0.161     -7.820      0.000      -1.570      -0.941
# total_ic_mou_8        -0.8950      0.136     -6.587      0.000      -1.161      -0.629
# spl_ic_mou_8          -0.5615      0.081     -6.903      0.000      -0.721      -0.402
# total_rech_num_8      -0.5802      0.051    -11.284      0.000      -0.681      -0.479
# last_day_rch_amt_8    -0.5543      0.051    -10.790      0.000      -0.655      -0.454
# monthly_2g_8          -0.5544      0.074     -7.513      0.000      -0.699      -0.410
# monthly_3g_8          -0.4733      0.067     -7.042      0.000      -0.605      -0.342
# arpu_diff             -0.5066      0.036    -13.965      0.000      -0.578      -0.435
# ======================================================================================
# ---------VIF-----------
#               Features    VIF
# 1         offnet_mou_7  19.39
# 5     std_og_t2m_mou_7  16.22
# 0          onnet_mou_7  10.52
# 4     std_og_t2t_mou_7   9.63
# 3     loc_og_t2m_mou_7   7.21
# 7     loc_ic_t2m_mou_8   5.35
# 6     loc_ic_t2m_mou_7   3.85
# 2     loc_og_t2t_mou_8   3.04
# 8       total_ic_mou_8   3.04
# 14           arpu_diff   1.40
# 10    total_rech_num_8   1.39
# 11  last_day_rch_amt_8   1.26
# 13        monthly_3g_8   1.10
# 12        monthly_2g_8   1.04
# 9         spl_ic_mou_8   1.03

# %%
#drop 'offnet_mou_7 ' because of high VIF and build the model.
X_train_m2_RFE = X_train_m2_RFE.drop('offnet_mou_7',axis=1)
build_model(X_train_m2_RFE)
# Out:
#                  Generalized Linear Model Regression Results
# ==============================================================================
# Dep. Variable:                      y   No. Observations:                21007
# Model:                            GLM   Df Residuals:                    20992
# Model Family:                Binomial   Df Model:                           14
# Link Function:                  logit   Scale:                          1.0000
# Method:                          IRLS   Log-Likelihood:                -4122.4
# Date:                Sat, 21 Aug 2021   Deviance:                       8244.7
# Time:                        17:38:19   Pearson chi2:                 6.71e+05
# No. Iterations:                     8
# Covariance Type:            nonrobust
# ======================================================================================
#                          coef    std err          z      P>|z|      [0.025      0.975]
# --------------------------------------------------------------------------------------
# const                 -4.0705      0.070    -57.943      0.000      -4.208      -3.933
# onnet_mou_7            0.6338      0.109      5.820      0.000       0.420       0.847
# loc_og_t2t_mou_8      -0.6983      0.105     -6.675      0.000      -0.903      -0.493
# loc_og_t2m_mou_7      -0.3325      0.057     -5.839      0.000      -0.444      -0.221
# std_og_t2t_mou_7      -0.6109      0.101     -6.029      0.000      -0.810      -0.412
# std_og_t2m_mou_7       0.0343      0.028      1.239      0.216      -0.020       0.089
# loc_ic_t2m_mou_7       0.6395      0.070      9.179      0.000       0.503       0.776
# loc_ic_t2m_mou_8      -1.3097      0.160     -8.199      0.000      -1.623      -0.997
# total_ic_mou_8        -0.8288      0.133     -6.225      0.000      -1.090      -0.568
# spl_ic_mou_8          -0.5731      0.082     -7.023      0.000      -0.733      -0.413
# total_rech_num_8      -0.5285      0.050    -10.540      0.000      -0.627      -0.430
# last_day_rch_amt_8    -0.4829      0.051     -9.557      0.000      -0.582      -0.384
# monthly_2g_8          -0.5493      0.073     -7.490      0.000      -0.693      -0.406
# monthly_3g_8          -0.4745      0.067     -7.060      0.000      -0.606      -0.343
# arpu_diff             -0.5339      0.037    -14.574      0.000      -0.606      -0.462
# ======================================================================================
# ---------VIF-----------
#               Features    VIF
# 0          onnet_mou_7  10.42
# 3     std_og_t2t_mou_7   9.51
# 6     loc_ic_t2m_mou_8   5.35
# 5     loc_ic_t2m_mou_7   3.84
# 7       total_ic_mou_8   3.03
# 1     loc_og_t2t_mou_8   3.01
# 2     loc_og_t2m_mou_7   1.66
# 13           arpu_diff   1.40
# 9     total_rech_num_8   1.39
# 10  last_day_rch_amt_8   1.24
# 4     std_og_t2m_mou_7   1.11
# 12        monthly_3g_8   1.10
# 11        monthly_2g_8   1.04
# 8         spl_ic_mou_8   1.03

# %%
#drop 'std_og_t2m_mou_7' because of high p-value and build the model.
X_train_m2_RFE = X_train_m2_RFE.drop('std_og_t2m_mou_7',axis=1)
build_model(X_train_m2_RFE)
# Out:
#                  Generalized Linear Model Regression Results
# ==============================================================================
# Dep. Variable:                      y   No. Observations:                21007
# Model:                            GLM   Df Residuals:                    20993
# Model Family:                Binomial   Df Model:                           13
# Link Function:                  logit   Scale:                          1.0000
# Method:                          IRLS   Log-Likelihood:                -4123.1
# Date:                Sat, 21 Aug 2021   Deviance:                       8246.2
# Time:                        17:38:38   Pearson chi2:                 6.76e+05
# No. Iterations:                     8
# Covariance Type:            nonrobust
# ======================================================================================
#                          coef    std err          z      P>|z|      [0.025      0.975]
# --------------------------------------------------------------------------------------
# const                 -4.0714      0.070    -57.977      0.000      -4.209      -3.934
# onnet_mou_7            0.6233      0.109      5.744      0.000       0.411       0.836
# loc_og_t2t_mou_8      -0.6973      0.105     -6.665      0.000      -0.902      -0.492
# loc_og_t2m_mou_7      -0.3356      0.057     -5.901      0.000      -0.447      -0.224
# std_og_t2t_mou_7      -0.6036      0.101     -5.971      0.000      -0.802      -0.406
# loc_ic_t2m_mou_7       0.6409      0.070      9.196      0.000       0.504       0.778
# loc_ic_t2m_mou_8      -1.3230      0.159     -8.306      0.000      -1.635      -1.011
# total_ic_mou_8        -0.8216      0.133     -6.189      0.000      -1.082      -0.561
# spl_ic_mou_8          -0.5701      0.082     -6.995      0.000      -0.730      -0.410
# total_rech_num_8      -0.5131      0.048    -10.613      0.000      -0.608      -0.418
# last_day_rch_amt_8    -0.4790      0.050     -9.518      0.000      -0.578      -0.380
# monthly_2g_8          -0.5522      0.073     -7.534      0.000      -0.696      -0.409
# monthly_3g_8          -0.4803      0.067     -7.155      0.000      -0.612      -0.349
# arpu_diff             -0.5426      0.036    -15.084      0.000      -0.613      -0.472
# ======================================================================================
# ---------VIF-----------
#               Features    VIF
# 0          onnet_mou_7  10.40
# 3     std_og_t2t_mou_7   9.50
# 5     loc_ic_t2m_mou_8   5.32
# 4     loc_ic_t2m_mou_7   3.84
# 6       total_ic_mou_8   3.02
# 1     loc_og_t2t_mou_8   3.01
# 2     loc_og_t2m_mou_7   1.66
# 12           arpu_diff   1.40
# 8     total_rech_num_8   1.33
# 9   last_day_rch_amt_8   1.24
# 11        monthly_3g_8   1.10
# 10        monthly_2g_8   1.04
# 7         spl_ic_mou_8   1.02

# %%
#drop 'onnet_mou_7' because of high VIF and build the model.
X_train_m2_RFE = X_train_m2_RFE.drop('onnet_mou_7',axis=1)
build_model(X_train_m2_RFE)
# Out:
#                  Generalized Linear Model Regression Results
# ==============================================================================
# Dep. Variable:                      y   No. Observations:                21007
# Model:                            GLM   Df Residuals:                    20994
# Model Family:                Binomial   Df Model:                           12
# Link Function:                  logit   Scale:                          1.0000
# Method:                          IRLS   Log-Likelihood:                -4139.6
# Date:                Sat, 21 Aug 2021   Deviance:                       8279.2
# Time:                        17:38:49   Pearson chi2:                 7.71e+05
# No. Iterations:                     8
# Covariance Type:            nonrobust
# ======================================================================================
#                          coef    std err          z      P>|z|      [0.025      0.975]
# --------------------------------------------------------------------------------------
# const                 -4.0521      0.070    -57.958      0.000      -4.189      -3.915
# loc_og_t2t_mou_8      -0.3616      0.086     -4.218      0.000      -0.530      -0.194
# loc_og_t2m_mou_7      -0.3231      0.056     -5.727      0.000      -0.434      -0.213
# std_og_t2t_mou_7      -0.0458      0.028     -1.631      0.103      -0.101       0.009
# loc_ic_t2m_mou_7       0.6619      0.070      9.480      0.000       0.525       0.799
# loc_ic_t2m_mou_8      -1.3868      0.160     -8.666      0.000      -1.700      -1.073
# total_ic_mou_8        -0.8276      0.134     -6.184      0.000      -1.090      -0.565
# spl_ic_mou_8          -0.5792      0.082     -7.079      0.000      -0.740      -0.419
# total_rech_num_8      -0.5018      0.048    -10.445      0.000      -0.596      -0.408
# last_day_rch_amt_8    -0.4707      0.050     -9.391      0.000      -0.569      -0.373
# monthly_2g_8          -0.5511      0.073     -7.526      0.000      -0.695      -0.408
# monthly_3g_8          -0.4809      0.067     -7.152      0.000      -0.613      -0.349
# arpu_diff             -0.5798      0.036    -16.321      0.000      -0.649      -0.510
# ======================================================================================
# ---------VIF-----------
#               Features   VIF
# 4     loc_ic_t2m_mou_8  5.31
# 3     loc_ic_t2m_mou_7  3.83
# 5       total_ic_mou_8  3.02
# 1     loc_og_t2m_mou_7  1.66
# 11           arpu_diff  1.35
# 7     total_rech_num_8  1.32
# 8   last_day_rch_amt_8  1.24
# 0     loc_og_t2t_mou_8  1.19
# 2     std_og_t2t_mou_7  1.12
# 10        monthly_3g_8  1.10
# 9         monthly_2g_8  1.04
# 6         spl_ic_mou_8  1.02

# %%
#drop 'std_og_t2t_mou_7' because of high p-value and build the model.
X_train_m2_RFE = X_train_m2_RFE.drop('std_og_t2t_mou_7',axis=1)
build_model(X_train_m2_RFE)
# Out:
#                  Generalized Linear Model Regression Results
# ==============================================================================
# Dep. Variable:                      y   No. Observations:                21007
# Model:                            GLM   Df Residuals:                    20995
# Model Family:                Binomial   Df Model:                           11
# Link Function:                  logit   Scale:                          1.0000
# Method:                          IRLS   Log-Likelihood:                -4140.9
# Date:                Sat, 21 Aug 2021   Deviance:                       8281.9
# Time:                        17:39:06   Pearson chi2:                 7.46e+05
# No. Iterations:                     8
# Covariance Type:            nonrobust
# ======================================================================================
#                          coef    std err          z      P>|z|      [0.025      0.975]
# --------------------------------------------------------------------------------------
# const                 -4.0481      0.070    -57.978      0.000      -4.185      -3.911
# loc_og_t2t_mou_8      -0.3562      0.086     -4.157      0.000      -0.524      -0.188
# loc_og_t2m_mou_7      -0.3151      0.056     -5.609      0.000      -0.425      -0.205
# loc_ic_t2m_mou_7       0.6608      0.070      9.470      0.000       0.524       0.798
# loc_ic_t2m_mou_8      -1.3706      0.160     -8.576      0.000      -1.684      -1.057
# total_ic_mou_8        -0.8330      0.134     -6.205      0.000      -1.096      -0.570
# spl_ic_mou_8          -0.5744      0.082     -7.042      0.000      -0.734      -0.415
# total_rech_num_8      -0.5201      0.047    -11.068      0.000      -0.612      -0.428
# last_day_rch_amt_8    -0.4803      0.050     -9.595      0.000      -0.578      -0.382
# monthly_2g_8          -0.5454      0.073     -7.458      0.000      -0.689      -0.402
# monthly_3g_8          -0.4718      0.067     -7.051      0.000      -0.603      -0.341
# arpu_diff             -0.5721      0.035    -16.275      0.000      -0.641      -0.503
# ======================================================================================
# ---------VIF-----------
#               Features   VIF
# 3     loc_ic_t2m_mou_8  5.29
# 2     loc_ic_t2m_mou_7  3.83
# 4       total_ic_mou_8  3.02
# 1     loc_og_t2m_mou_7  1.64
# 10           arpu_diff  1.35
# 6     total_rech_num_8  1.27
# 7   last_day_rch_amt_8  1.24
# 0     loc_og_t2t_mou_8  1.18
# 9         monthly_3g_8  1.08
# 8         monthly_2g_8  1.03
# 5         spl_ic_mou_8  1.02

# %%
#Get the Coeff of the Features.
X_train_sm = sm.add_constant(X_train_m2_RFE) # add constant to the dataset.
model_2 = sm.GLM(y_train_m2.values.reshape(-1,1),X_train_sm, family = sm.families.Binomial())  #create a model
model_2 = model_2.fit()                #fit the model

#Get the odd ration
odds = np.exp(model_2.params)
pd.DataFrame(odds,X_train_m2_RFE.columns,columns=['Coeff']).sort_values(by="Coeff",ascending=False)
# Out:
#                        Coeff
# loc_ic_t2m_mou_7    1.936248
# loc_og_t2m_mou_7    0.729723
# loc_og_t2t_mou_8    0.700346
# monthly_3g_8        0.623855
# last_day_rch_amt_8  0.618598
# total_rech_num_8    0.594475
# monthly_2g_8        0.579633
# arpu_diff           0.564362
# spl_ic_mou_8        0.563037
# total_ic_mou_8      0.434762
# loc_ic_t2m_mou_8    0.253945

# %%
#Visualize top features.
modlog =pd.DataFrame(odds,X_train_m2_RFE.columns,columns=['Coeff']).sort_values(by="Coeff",ascending=False)

ax = plt.subplots(figsize=(10,5))
ax = sns.barplot(x=modlog['Coeff'],y=modlog.index)
ax.set_title("Visualize Feature Importance")
ax.set_yticklabels(modlog.index)
ax.set_xlabel("Feature Importance Score")
ax.set_ylabel("Features")
plt.show()
